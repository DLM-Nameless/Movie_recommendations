# %%
import requests
import json

# Llave de API de The Movie DB
api_key = "a88fba1e1f31a7d6a5069ba558f0b210"

# URL base para la API de The Movie DB
base_url = "https://api.themoviedb.org/3/"

# Endpoint para obtener todas las películas
movies_endpoint = "discover/movie"

# Parámetros para la consulta a la API
params = {
    "api_key": api_key,
    "sort_by": "popularity.desc",
    "language": "es-MX",
    "with_original_language": "en",
    "timezone": "America/Mexico_City",
    "with_watch_monetization_types": "flatrate",
    "page": 1,
    "include_adult": False
}

# Lista vacía para almacenar los datos de las películas
movies_data = []

# Loop para recorrer todas las páginas de resultados
while params["page"] <= 200: # Limitar a 1000 resultados
    # Hacer la petición GET a la API
    response = requests.get(base_url + movies_endpoint, params=params)
    # Convertir la respuesta a JSON
    response_json = json.loads(response.content)
    # Obtener los resultados de la consulta
    results = response_json["results"]
    # Si no hay más resultados, salir del loop
    if not results:
        break
    # Loop para procesar los resultados de la página actual
    for result in results:
        # Obtener los datos de la película
        movie_data = {
            "nombre": result["title"],
            "calificacion": result["vote_average"],
            "streaming": []
        }
        # Obtener los IDs de los géneros de la película
        genre_ids = result['genre_ids']
        # Obtener los nombres de los géneros correspondientes a los IDs de género
        genre_names = []
        for genre_id in genre_ids:
            genre_url = f'https://api.themoviedb.org/3/genre/movie/list?api_key={api_key}'
            genre_response = requests.get(genre_url)
            genre_data = genre_response.json()
            genre_names.append([genre['name'] for genre in genre_data['genres'] if genre['id'] == genre_id][0])
        movie_data['genero'] = genre_names
        # Obtener los datos de transmisión de la película
        streaming_endpoint = f"movie/{result['id']}/watch/providers"
        streaming_params = {
            "api_key": api_key,
            "region": "MX"
        }
        streaming_response = requests.get(base_url + streaming_endpoint, params=streaming_params)
        streaming_response_json = json.loads(streaming_response.content)
        if "results" in streaming_response_json and "MX" in streaming_response_json["results"]:
            results_mx = streaming_response_json["results"]["MX"]
            if "flatrate" in results_mx:
                for provider in results_mx["flatrate"]:
                    movie_data["streaming"].append(provider["provider_name"])
        # Agregar los datos de la película a la lista
        movies_data.append(movie_data)
    # Incrementar el número de página para la siguiente consulta
    params["page"] += 1

# Imprimir los datos de las películas
for movie in movies_data:
    print(movie)
# Out:
# {'nombre': 'Super Mario Bros. La película', 'calificacion': 7.5, 'streaming': [], 'genero': ['Animation', 'Adventure', 'Family', 'Fantasy', 'Comedy']}
# {'nombre': '¡Shazam! La furia de los dioses', 'calificacion': 6.9, 'streaming': [], 'genero': ['Action', 'Comedy', 'Fantasy']}
# {'nombre': 'Avatar: El camino del agua', 'calificacion': 7.7, 'streaming': [], 'genero': ['Science Fiction', 'Adventure', 'Action']}
# {'nombre': 'Ant-Man and the Wasp: Quantumania', 'calificacion': 6.5, 'streaming': [], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Creed III', 'calificacion': 7.3, 'streaming': [], 'genero': ['Drama', 'Action']}
# {'nombre': 'Misterio a la vista', 'calificacion': 6.6, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Mystery', 'Action']}
# {'nombre': 'Gato con Botas: El último deseo', 'calificacion': 8.3, 'streaming': [], 'genero': ['Animation', 'Family', 'Fantasy', 'Adventure', 'Comedy']}
# {'nombre': 'John Wick 4', 'calificacion': 8, 'streaming': [], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': '65: Al borde de la extinción', 'calificacion': 6.3, 'streaming': [], 'genero': ['Science Fiction', 'Adventure', 'Thriller', 'Action']}
# {'nombre': 'Gangs of Lagos', 'calificacion': 5.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Crime']}
# {'nombre': 'Chupa', 'calificacion': 6.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Adventure', 'Fantasy', 'Family']}
# {'nombre': 'Oso intoxicado', 'calificacion': 6.4, 'streaming': [], 'genero': ['Thriller', 'Comedy', 'Crime']}
# {'nombre': 'Evil Dead: El despertar', 'calificacion': 7.1, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'El exorcista del papa', 'calificacion': 6.6, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Cazador de tormentas (Supercell)', 'calificacion': 6.3, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Attack on Titan', 'calificacion': 6.2, 'streaming': [], 'genero': ['Action', 'Science Fiction']}
# {'nombre': 'Pantera Negra: Wakanda por siempre', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Winnie the Pooh: Sangre y Miel', 'calificacion': 5.8, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Black Adam', 'calificacion': 7.1, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Science Fiction', 'Fantasy']}
# {'nombre': 'Siete reyes deben morir', 'calificacion': 7.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Adventure', 'History', 'Drama', 'War']}
# {'nombre': 'The Park', 'calificacion': 5.9, 'streaming': [], 'genero': ['Action', 'Drama', 'Horror', 'Science Fiction', 'Thriller']}
# {'nombre': 'LAS AVENTURAS DE MAURICE', 'calificacion': 6.9, 'streaming': [], 'genero': ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Rey del anillo: La historia de Jem Belcher', 'calificacion': 6.2, 'streaming': [], 'genero': ['Drama', 'History']}
# {'nombre': 'Alerta extrema', 'calificacion': 6.9, 'streaming': [], 'genero': ['Action', 'Adventure', 'Thriller']}
# {'nombre': 'LA CONSPIRACIÓN DEL DIABLO', 'calificacion': 6.4, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Llaman a la puerta', 'calificacion': 6.4, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'La Resurrección de la Momia', 'calificacion': 6.2, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Hart: Duro de entrenar', 'calificacion': 6.1, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Comedy', 'Thriller']}
# {'nombre': 'Bodas de plomo', 'calificacion': 6.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Comedy', 'Romance']}
# {'nombre': 'M3GAN', 'calificacion': 7.4, 'streaming': [], 'genero': ['Science Fiction', 'Horror', 'Comedy']}
# {'nombre': 'Rápidos y furiosos X', 'calificacion': 0, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Batman: La Perdición que llegó a Ciudad Gótica', 'calificacion': 6.4, 'streaming': [], 'genero': ['Animation', 'Fantasy', 'Horror', 'Action', 'Mystery']}
# {'nombre': 'La elefanta del Mago', 'calificacion': 7.3, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Adventure', 'Family', 'Fantasy']}
# {'nombre': 'Vértigo', 'calificacion': 7.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Thriller', 'Drama']}
# {'nombre': 'Tiburones en La Luna', 'calificacion': 5.3, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Thriller', 'Horror']}
# {'nombre': 'El clímax del millón: La historia de Pornhub', 'calificacion': 5.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Documentary']}
# {'nombre': 'LA CONSAGRACIÓN', 'calificacion': 6.5, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Matilda, de Roald Dahl: El musical', 'calificacion': 6.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Family', 'Comedy', 'Fantasy']}
# {'nombre': 'Encanto en El Hollywood Bowl', 'calificacion': 7.2, 'streaming': ['Disney Plus'], 'genero': ['Music']}
# {'nombre': 'Sonic 2: La Película', 'calificacion': 7.6, 'streaming': ['Star Plus'], 'genero': ['Action', 'Adventure', 'Family', 'Comedy']}
# {'nombre': 'Legión de superhéroes', 'calificacion': 6.3, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Action', 'Science Fiction']}
# {'nombre': 'John Wick: Chapter 5', 'calificacion': 0, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Black Warrant', 'calificacion': 5.6, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'La luz del diablo', 'calificacion': 7.1, 'streaming': ['Amazon Prime Video'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Calabozos & Dragones: Honor entre ladrones', 'calificacion': 7.4, 'streaming': [], 'genero': ['Adventure', 'Fantasy', 'Comedy']}
# {'nombre': 'H.P. Lovecraft’s Witch House', 'calificacion': 5.8, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Los Simpson cononcen a los Bocelli en Feliz Navidad', 'calificacion': 5.2, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy']}
# {'nombre': 'Spider-Man: Sin camino a casa', 'calificacion': 8, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'El atracador perfecto', 'calificacion': 6.2, 'streaming': [], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Thor: Amor y Trueno', 'calificacion': 6.6, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Action', 'Comedy']}
# {'nombre': 'Top Gun: Maverick', 'calificacion': 8.3, 'streaming': ['Star Plus', 'Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Action', 'Drama']}
# {'nombre': 'Sick', 'calificacion': 6.3, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Little Dixie', 'calificacion': 6, 'streaming': [], 'genero': ['Thriller', 'Action', 'Drama', 'Crime']}
# {'nombre': 'Geo-Tormenta', 'calificacion': 6.1, 'streaming': ['HBO Max'], 'genero': ['Action', 'Science Fiction', 'Thriller']}
# {'nombre': 'Jurassic World Dominio', 'calificacion': 6.9, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Action', 'Science Fiction']}
# {'nombre': 'Las crónicas de Narnia: El león, la bruja y el ropero', 'calificacion': 7.1, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Family', 'Fantasy']}
# {'nombre': 'Super Mario Bros.', 'calificacion': 4.3, 'streaming': [], 'genero': ['Adventure', 'Fantasy', 'Comedy', 'Family', 'Science Fiction']}
# {'nombre': 'Posesión Infernal', 'calificacion': 6.5, 'streaming': ['HBO Max'], 'genero': ['Horror']}
# {'nombre': 'John Wick 2: Un Nuevo Día Para Matar', 'calificacion': 7.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'Luck', 'calificacion': 7.9, 'streaming': ['Apple TV Plus'], 'genero': ['Animation', 'Adventure', 'Comedy', 'Fantasy']}
# {'nombre': 'La Mujer Rey', 'calificacion': 7.8, 'streaming': [], 'genero': ['Action', 'Drama', 'History']}
# {'nombre': 'El asesino perfecto', 'calificacion': 7.4, 'streaming': [], 'genero': ['Action', 'Crime', 'Drama', 'Thriller']}
# {'nombre': 'Noche sin paz', 'calificacion': 7.6, 'streaming': [], 'genero': ['Action', 'Comedy', 'Crime', 'Thriller']}
# {'nombre': 'Lord of the Streets', 'calificacion': 5.3, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Hex', 'calificacion': 6.1, 'streaming': [], 'genero': ['Action', 'Horror', 'Thriller']}
# {'nombre': 'Historia de honor', 'calificacion': 7.3, 'streaming': ['Amazon Prime Video'], 'genero': ['War', 'History', 'Drama']}
# {'nombre': 'R.I.P.D. 2: La rebelión de los condenados', 'calificacion': 6.6, 'streaming': [], 'genero': ['Action', 'Comedy', 'Fantasy', 'Crime']}
# {'nombre': 'Un jefe en pañales: Especial de Navidad', 'calificacion': 6.8, 'streaming': ['Netflix'], 'genero': ['Animation', 'Family', 'Adventure']}
# {'nombre': 'John Wick 3: Parabellum', 'calificacion': 7.4, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'Transfusion', 'calificacion': 6.4, 'streaming': [], 'genero': ['Crime', 'Thriller', 'Drama']}
# {'nombre': 'Depredador: La presa', 'calificacion': 7.8, 'streaming': ['Star Plus'], 'genero': ['Thriller', 'Action', 'Science Fiction']}
# {'nombre': 'Pinocho de Guillermo del Toro', 'calificacion': 8.2, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Fantasy', 'Drama', 'Music']}
# {'nombre': 'Barbie Skipper Y La Gran Aventura Como Niñera', 'calificacion': 7.3, 'streaming': [], 'genero': ['Family', 'Animation']}
# {'nombre': 'Adicción perfecta', 'calificacion': 6.7, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Romance', 'Action']}
# {'nombre': 'TERRIFIER 2: EL PAYASO SINIESTRO', 'calificacion': 6.9, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'La ballena', 'calificacion': 8.1, 'streaming': [], 'genero': ['Drama']}
# {'nombre': 'Medieval', 'calificacion': 7.2, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Drama', 'History']}
# {'nombre': 'Doctor Strange en el multiverso de la locura', 'calificacion': 7.4, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Action', 'Adventure']}
# {'nombre': 'Avengers: Infinity War', 'calificacion': 8.3, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Science Fiction']}
# {'nombre': 'Scream 6', 'calificacion': 7.3, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Minions: Nace un villano', 'calificacion': 7.4, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'Géminis: El planeta oscuro', 'calificacion': 5.8, 'streaming': [], 'genero': ['Science Fiction', 'Horror']}
# {'nombre': 'Red', 'calificacion': 7.5, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy', 'Fantasy']}
# {'nombre': 'Power Rangers: Ayer, hoy y siempre', 'calificacion': 7, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Science Fiction', 'Fantasy']}
# {'nombre': 'Encanto', 'calificacion': 7.6, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Avatar', 'calificacion': 7.6, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Sonríe', 'calificacion': 6.8, 'streaming': ['Star Plus', 'Paramount Plus', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Godzilla vs Kong', 'calificacion': 7.7, 'streaming': ['Amazon Prime Video', 'HBO Max', 'DIRECTV GO'], 'genero': ['Action', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Adrenaline', 'calificacion': 4, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Scream 5', 'calificacion': 6.7, 'streaming': ['Star Plus'], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Maravilloso Desastre', 'calificacion': 6.7, 'streaming': [], 'genero': ['Romance', 'Drama', 'Comedy']}
# {'nombre': 'Detective Knight: Independencia', 'calificacion': 5.6, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'A Good Person', 'calificacion': 6.9, 'streaming': [], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'Cruel Fixation', 'calificacion': 6.9, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Batman', 'calificacion': 7.7, 'streaming': ['HBO Max'], 'genero': ['Crime', 'Mystery', 'Thriller']}
# {'nombre': 'Un mundo extraño', 'calificacion': 6.5, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Science Fiction']}
# {'nombre': 'No hay santos', 'calificacion': 5.3, 'streaming': [], 'genero': ['Action', 'Mystery', 'Thriller']}
# {'nombre': 'Shrek', 'calificacion': 7.7, 'streaming': ['Amazon Prime Video'], 'genero': ['Animation', 'Comedy', 'Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Lilo, Lilo, cocodrilo', 'calificacion': 7.4, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Family', 'Music']}
# {'nombre': 'Hotel Transylvania 4: Transformanía', 'calificacion': 7.1, 'streaming': ['Amazon Prime Video'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy', 'Adventure']}
# {'nombre': 'El Exorcismo de Dios', 'calificacion': 7.2, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Guardianes de la Galaxia volumen 3', 'calificacion': 0, 'streaming': [], 'genero': ['Science Fiction', 'Adventure', 'Action']}
# {'nombre': 'Un vecino gruñón', 'calificacion': 7.9, 'streaming': [], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'Glass Onion: Un misterio de Knives Out', 'calificacion': 7.1, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Crime', 'Mystery']}
# {'nombre': 'La reencarnación del demonio', 'calificacion': 5.8, 'streaming': [], 'genero': ['Horror', 'Thriller', 'Mystery']}
# {'nombre': 'John Wick 1: Otro Día Para Matar', 'calificacion': 7.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Sing 2: ¡Ven y canta de nuevo!', 'calificacion': 8, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Family']}
# {'nombre': 'Kids vs. Aliens', 'calificacion': 6, 'streaming': [], 'genero': ['Science Fiction', 'Horror', 'Adventure', 'Action']}
# {'nombre': 'Wait With Me', 'calificacion': 2.7, 'streaming': [], 'genero': ['Romance']}
# {'nombre': 'El rio de la ira', 'calificacion': 6.6, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Bestia', 'calificacion': 6.8, 'streaming': ['HBO Max'], 'genero': ['Thriller', 'Action', 'Horror', 'Adventure']}
# {'nombre': 'Desencantada', 'calificacion': 7, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Prancer: A Christmas Tale', 'calificacion': 6.6, 'streaming': [], 'genero': ['Family', 'Fantasy']}
# {'nombre': 'Ofrenda Al Demonio', 'calificacion': 5.7, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Agente oculto', 'calificacion': 6.4, 'streaming': [], 'genero': ['Thriller', 'Drama']}
# {'nombre': 'Piratas del Caribe: Navegando aguas misteriosas', 'calificacion': 6.5, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Fantasy']}
# {'nombre': 'Efecto nocebo', 'calificacion': 6.3, 'streaming': [], 'genero': ['Mystery', 'Thriller', 'Horror']}
# {'nombre': 'La espada de los 47 Ronin', 'calificacion': 6.6, 'streaming': [], 'genero': ['Action', 'Drama', 'Fantasy', 'Thriller']}
# {'nombre': 'Una noche en el museo: El regreso de Kahmunrah', 'calificacion': 6.9, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Harry Potter y la piedra filosofal', 'calificacion': 7.9, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Marcel, el caracol con zapatos', 'calificacion': 7.8, 'streaming': [], 'genero': ['Animation', 'Comedy', 'Family', 'Drama', 'Adventure']}
# {'nombre': 'Of an Age', 'calificacion': 7.3, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Super rápidos y mega furiosos', 'calificacion': 5, 'streaming': [], 'genero': ['Comedy', 'Action']}
# {'nombre': 'Tren bala', 'calificacion': 7.5, 'streaming': ['HBO Max'], 'genero': ['Action', 'Comedy', 'Thriller']}
# {'nombre': 'Rápidos y furiosos 9', 'calificacion': 7.2, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Crime', 'Thriller']}
# {'nombre': 'Al filo del abismo', 'calificacion': 6.5, 'streaming': ['Amazon Prime Video'], 'genero': ['Thriller', 'Adventure']}
# {'nombre': 'Candy Land', 'calificacion': 6.5, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'The Price We Pay', 'calificacion': 5.9, 'streaming': [], 'genero': ['Action', 'Thriller', 'Mystery', 'Crime', 'Horror']}
# {'nombre': 'Mar de sangre', 'calificacion': 5.9, 'streaming': [], 'genero': ['Horror', 'Thriller', 'Action', 'Adventure']}
# {'nombre': 'After: Amor Infinito', 'calificacion': 6.9, 'streaming': ['Amazon Prime Video'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'Adentro', 'calificacion': 5.9, 'streaming': [], 'genero': ['Drama', 'Thriller']}
# {'nombre': 'La ciudad perdida', 'calificacion': 6.6, 'streaming': ['Star Plus'], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': 'El despertar del diablo', 'calificacion': 7.3, 'streaming': ['HBO Max'], 'genero': ['Horror']}
# {'nombre': 'Dirty Little Secret', 'calificacion': 7.3, 'streaming': [], 'genero': ['Drama', 'TV Movie']}
# {'nombre': 'Magic Mike: El último baile', 'calificacion': 7.2, 'streaming': [], 'genero': ['Comedy', 'Drama', 'Romance']}
# {'nombre': 'Harry Potter y el cáliz de fuego', 'calificacion': 7.8, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy', 'Family']}
# {'nombre': 'Harry Potter y la cámara secreta', 'calificacion': 7.7, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'After: En mil pedazos', 'calificacion': 7.2, 'streaming': ['Amazon Prime Video'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'Transformers: El despertar de las bestias', 'calificacion': 0, 'streaming': [], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'La Era de Hielo: Las aventuras de Buck', 'calificacion': 6.7, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Adventure', 'Family']}
# {'nombre': 'Abracadabra 2', 'calificacion': 7.4, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Comedy', 'Family']}
# {'nombre': 'La sirenita', 'calificacion': 0, 'streaming': [], 'genero': ['Adventure', 'Family', 'Fantasy', 'Romance']}
# {'nombre': 'La Máquina infernal', 'calificacion': 6.6, 'streaming': ['Star Plus', 'Paramount Plus', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Thriller', 'Mystery']}
# {'nombre': 'DC Liga De Supermascotas', 'calificacion': 7.4, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Action', 'Family', 'Comedy', 'Science Fiction']}
# {'nombre': 'Harry Potter y el misterio del príncipe', 'calificacion': 7.7, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Tom y Jerry en la Tierra de Nieve', 'calificacion': 6.9, 'streaming': [], 'genero': ['Family', 'Comedy', 'Animation', 'Adventure']}
# {'nombre': 'Cincuenta sombras de Grey', 'calificacion': 5.9, 'streaming': ['Netflix', 'Star Plus', 'Paramount Plus', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Netflix basic with Ads', 'Paramount Plus Apple TV Channel '], 'genero': ['Drama', 'Romance', 'Thriller']}
# {'nombre': 'Hasta el último hombre', 'calificacion': 8.2, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Drama', 'History', 'War']}
# {'nombre': 'Rápidos y Furiosos: Hobbs y Shaw', 'calificacion': 6.9, 'streaming': [], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': 'La noche del demonio: La puerta roja', 'calificacion': 0, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Uncharted: Fuera del mapa', 'calificacion': 7, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure']}
# {'nombre': 'The Lair', 'calificacion': 5.8, 'streaming': [], 'genero': ['Horror', 'Action']}
# {'nombre': 'Ghosteado', 'calificacion': 7.2, 'streaming': ['Apple TV Plus'], 'genero': ['Romance', 'Action', 'Comedy']}
# {'nombre': 'Tetris', 'calificacion': 7.8, 'streaming': ['Apple TV Plus'], 'genero': ['Thriller', 'History', 'Drama']}
# {'nombre': 'Lobo adolescente - La película', 'calificacion': 7.8, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Action', 'Fantasy', 'TV Movie']}
# {'nombre': 'Creed II: Defendiendo el Legado', 'calificacion': 7, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama']}
# {'nombre': 'Una peli de fútbol... y mutantes', 'calificacion': 6.1, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'The Avengers: Los Vengadores', 'calificacion': 7.7, 'streaming': ['Disney Plus'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'La Liga de la Justicia de Zack Snyder', 'calificacion': 8.2, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Wolf Hound', 'calificacion': 6.6, 'streaming': [], 'genero': ['War', 'Action']}
# {'nombre': 'Lightyear', 'calificacion': 7.1, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Action', 'Adventure', 'Family', 'Science Fiction']}
# {'nombre': 'Orgasm Inc: La historia de OneTaste', 'calificacion': 6.4, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Documentary']}
# {'nombre': 'Cincuenta sombras liberadas', 'calificacion': 6.7, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Creed: Corazón de campeón', 'calificacion': 7.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama']}
# {'nombre': 'Un jefe en pañales 2: Negocios de familia', 'calificacion': 7.5, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Comedy', 'Adventure', 'Family']}
# {'nombre': 'Piratas del Caribe: En el Fin del Mundo', 'calificacion': 7.2, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'Venom: Carnage Liberado', 'calificacion': 6.9, 'streaming': ['HBO Max'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'Monsters, Inc.', 'calificacion': 7.8, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'Agente Fortune: El gran engaño', 'calificacion': 6.7, 'streaming': [], 'genero': ['Action', 'Comedy', 'Adventure']}
# {'nombre': 'Cars 3', 'calificacion': 6.9, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Adventure', 'Comedy', 'Family']}
# {'nombre': 'Desamparados', 'calificacion': 6.3, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Shrek 2', 'calificacion': 7.2, 'streaming': ['Netflix', 'Amazon Prime Video', 'HBO Max', 'Netflix basic with Ads'], 'genero': ['Animation', 'Family', 'Comedy', 'Fantasy', 'Adventure', 'Romance']}
# {'nombre': 'Animales fantásticos: Los secretos de Dumbledore', 'calificacion': 6.8, 'streaming': ['HBO Max'], 'genero': ['Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Interestelar', 'calificacion': 8.4, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Adventure', 'Drama', 'Science Fiction']}
# {'nombre': 'Harry Potter y el prisionero de Azkaban', 'calificacion': 8, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'La Escuela del Bien y del Mal', 'calificacion': 7.2, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Fantasy']}
# {'nombre': 'La huérfana: El origen', 'calificacion': 6.8, 'streaming': ['Amazon Prime Video'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Némesis', 'calificacion': 6.8, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Crime', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Emily la criminal', 'calificacion': 6.8, 'streaming': [], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Vista por última vez', 'calificacion': 6.6, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Piratas del Caribe: La maldición de la Perla Negra', 'calificacion': 7.8, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'Los Caballeros del Zodiaco: Saint Seiya - El inicio', 'calificacion': 0, 'streaming': [], 'genero': ['Fantasy', 'Action', 'Adventure']}
# {'nombre': 'Una historia del Bronx', 'calificacion': 7.8, 'streaming': [], 'genero': ['Drama', 'Crime']}
# {'nombre': 'Cruella', 'calificacion': 8.1, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Crime']}
# {'nombre': 'Detective Knight: Sin piedad', 'calificacion': 6.8, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Mortal Kombat', 'calificacion': 7.1, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Fantasy', 'Adventure']}
# {'nombre': 'On a Wing and a Prayer', 'calificacion': 6.6, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Thriller']}
# {'nombre': 'El Hombre del Norte', 'calificacion': 7.1, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': '¿Y qué tendrá que ver el amor?', 'calificacion': 6.5, 'streaming': [], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Ralph, el demoledor', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Comedy', 'Adventure']}
# {'nombre': 'El teléfono negro', 'calificacion': 7.8, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Enredados', 'calificacion': 7.6, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family']}
# {'nombre': 'Secuestro en directo', 'calificacion': 6.2, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Talentos Ocultos', 'calificacion': 8.1, 'streaming': ['Disney Plus'], 'genero': ['Drama', 'History']}
# {'nombre': 'Ratatouille', 'calificacion': 7.8, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Out of the Blue', 'calificacion': 4.6, 'streaming': [], 'genero': ['Thriller', 'Romance']}
# {'nombre': 'El rey león', 'calificacion': 8.3, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Drama']}
# {'nombre': 'Asesino sin memoria', 'calificacion': 7, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'El vengador', 'calificacion': 7.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Crime', 'Thriller']}
# {'nombre': 'Harry Potter y la orden del Fénix', 'calificacion': 7.7, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy', 'Mystery']}
# {'nombre': 'Moonfall: Impacto Lunar', 'calificacion': 6.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Science Fiction', 'Adventure', 'Action']}
# {'nombre': 'Praise This', 'calificacion': 7.7, 'streaming': [], 'genero': ['Comedy', 'Music']}
# {'nombre': 'Babylon', 'calificacion': 7.5, 'streaming': [], 'genero': ['Drama', 'Comedy']}
# {'nombre': 'Power Rangers', 'calificacion': 6.3, 'streaming': ['Netflix', 'Amazon Prime Video', 'Netflix basic with Ads'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Piratas del Caribe: El cofre de la muerte', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'El Conjuro 3: El Diablo me Obligó a Hacerlo', 'calificacion': 7.5, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Coco', 'calificacion': 8.2, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Fantasy', 'Music', 'Comedy', 'Adventure']}
# {'nombre': 'Shang-Chi y la leyenda de los Diez Anillos', 'calificacion': 7.6, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Air: La historia detrás del logo', 'calificacion': 7.7, 'streaming': [], 'genero': ['Drama']}
# {'nombre': 'La Gran Aventura de Blue en la Ciudad', 'calificacion': 7.4, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Family', 'Adventure', 'Music', 'Animation']}
# {'nombre': 'Harry Potter y las reliquias de la muerte: Parte 2', 'calificacion': 8.1, 'streaming': ['HBO Max'], 'genero': ['Fantasy', 'Adventure']}
# {'nombre': '¡Shazam!', 'calificacion': 7, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Comedy', 'Fantasy']}
# {'nombre': 'Clifford: El Gran Perro Rojo', 'calificacion': 7.2, 'streaming': ['Star Plus'], 'genero': ['Family', 'Adventure', 'Comedy', 'Fantasy']}
# {'nombre': 'Luca', 'calificacion': 7.9, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Coraline y la puerta secreta', 'calificacion': 7.8, 'streaming': [], 'genero': ['Animation', 'Family', 'Fantasy']}
# {'nombre': 'Monstruo del mar', 'calificacion': 7.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Adventure', 'Family', 'Fantasy']}
# {'nombre': 'Justicia Implacable', 'calificacion': 7.7, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Adventure', 'Crime', 'Thriller']}
# {'nombre': 'Toy Story', 'calificacion': 8, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Adventure', 'Family', 'Comedy']}
# {'nombre': 'The Minute You Wake Up Dead', 'calificacion': 5.8, 'streaming': [], 'genero': ['Thriller', 'Crime']}
# {'nombre': 'La sirenita', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Fantasy']}
# {'nombre': 'High Heat', 'calificacion': 6, 'streaming': [], 'genero': ['Action', 'Comedy', 'Crime']}
# {'nombre': 'Morbius', 'calificacion': 6.2, 'streaming': ['HBO Max'], 'genero': ['Action', 'Science Fiction', 'Fantasy']}
# {'nombre': 'Los reyes de la calle Mulberry: ¡Que reine el amor!', 'calificacion': 5.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Drama', 'Adventure']}
# {'nombre': 'Jack en la caja maldita 2: El despertar', 'calificacion': 6.4, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Maze Runner: Correr o morir', 'calificacion': 7.2, 'streaming': ['Star Plus'], 'genero': ['Action', 'Mystery', 'Science Fiction', 'Thriller']}
# {'nombre': 'La era de hielo', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Adventure']}
# {'nombre': 'Cars 2', 'calificacion': 6.1, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Comedy']}
# {'nombre': 'Big Hero 6', 'calificacion': 7.7, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Family', 'Animation', 'Action', 'Comedy']}
# {'nombre': 'Rápidos y furiosos 8', 'calificacion': 6.9, 'streaming': ['Star Plus'], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Godzilla: Rey De Los Monstruos', 'calificacion': 6.7, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Science Fiction', 'Action']}
# {'nombre': 'Quiebre', 'calificacion': 6.7, 'streaming': [], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Dog: Un viaje salvaje', 'calificacion': 7.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Comedy']}
# {'nombre': 'Avengers: Endgame', 'calificacion': 8.3, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Science Fiction', 'Action']}
# {'nombre': 'Un paraíso peligroso', 'calificacion': 5.8, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Raya y el último dragón', 'calificacion': 7.9, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Fantasy', 'Action', 'Adventure']}
# {'nombre': 'El Misterio de Ozarks', 'calificacion': 6.3, 'streaming': [], 'genero': ['Western', 'Horror', 'Mystery']}
# {'nombre': 'Shrek Para Siempre el Capítulo Final', 'calificacion': 6.3, 'streaming': [], 'genero': ['Comedy', 'Adventure', 'Fantasy', 'Animation', 'Family']}
# {'nombre': 'El Entresuelo', 'calificacion': 6.5, 'streaming': ['Star Plus'], 'genero': ['Thriller']}
# {'nombre': 'Los Tipos Malos', 'calificacion': 7.7, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Action', 'Adventure', 'Crime', 'Comedy', 'Family']}
# {'nombre': 'Avengers: Era de Ultrón', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Intensa Mente', 'calificacion': 7.9, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Drama', 'Comedy']}
# {'nombre': 'Crepúsculo', 'calificacion': 6.3, 'streaming': ['Netflix', 'Amazon Prime Video', 'Starz Play Amazon Channel', 'Netflix basic with Ads', 'Lionsgate Plus'], 'genero': ['Fantasy', 'Drama', 'Romance']}
# {'nombre': 'Invitación al Infierno', 'calificacion': 6.3, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Los Croods 2: Una Nueva Era', 'calificacion': 7.5, 'streaming': [], 'genero': ['Animation', 'Family', 'Adventure', 'Fantasy', 'Comedy']}
# {'nombre': 'Harry Potter y las reliquias de la muerte (1ª parte)', 'calificacion': 7.8, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Rápidos y Furiosos 7', 'calificacion': 7.2, 'streaming': ['HBO Max'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'Titanic', 'calificacion': 7.9, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'El Amanecer Del Planeta De Los Simios', 'calificacion': 7.3, 'streaming': ['Star Plus'], 'genero': ['Science Fiction', 'Action', 'Drama', 'Thriller']}
# {'nombre': 'The Independent', 'calificacion': 7.3, 'streaming': [], 'genero': ['Thriller', 'Drama']}
# {'nombre': 'Los campeones', 'calificacion': 7, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': '¡Nop!', 'calificacion': 6.9, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Mystery', 'Science Fiction']}
# {'nombre': 'Renfield: Asistente de vampiro', 'calificacion': 6.8, 'streaming': [], 'genero': ['Comedy', 'Horror', 'Fantasy']}
# {'nombre': 'La Guerra Del Mañana', 'calificacion': 7.9, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Science Fiction', 'Adventure']}
# {'nombre': 'El lobo de Wall Street', 'calificacion': 8, 'streaming': ['HBO Max'], 'genero': ['Crime', 'Drama', 'Comedy']}
# {'nombre': 'Resident Evil: Bienvenidos a Raccoon City', 'calificacion': 6.1, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Science Fiction', 'Action']}
# {'nombre': 'Susurro', 'calificacion': 6.4, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Rescatando al soldado Ryan', 'calificacion': 8.2, 'streaming': [], 'genero': ['Drama', 'History', 'War']}
# {'nombre': 'Arctic Void', 'calificacion': 5, 'streaming': [], 'genero': ['Science Fiction', 'Thriller']}
# {'nombre': 'X', 'calificacion': 6.8, 'streaming': ['Amazon Prime Video'], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Invicto 3: Redención', 'calificacion': 7.5, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Maneater', 'calificacion': 4.9, 'streaming': [], 'genero': ['Mystery', 'Thriller', 'Horror']}
# {'nombre': 'Lou', 'calificacion': 6.7, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Son como niños 2', 'calificacion': 6.1, 'streaming': ['HBO Max'], 'genero': ['Comedy']}
# {'nombre': 'El Último Dragón', 'calificacion': 6.9, 'streaming': ['Amazon Prime Video'], 'genero': ['Fantasy', 'Adventure', 'Action']}
# {'nombre': 'Todo en todas partes al mismo tiempo', 'calificacion': 7.9, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Gigantes de Acero', 'calificacion': 7, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Drama']}
# {'nombre': 'El cuartel secreto', 'calificacion': 6.8, 'streaming': ['Star Plus', 'Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel'], 'genero': ['Action', 'Adventure', 'Comedy', 'Science Fiction', 'Family']}
# {'nombre': 'Eternals', 'calificacion': 7, 'streaming': ['Disney Plus'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'After: Aquí empieza todo', 'calificacion': 7.2, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'Mulán', 'calificacion': 7.9, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure']}
# {'nombre': 'La noche del demonio', 'calificacion': 6.9, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Yo antes de ti', 'calificacion': 7.9, 'streaming': ['Amazon Prime Video', 'MGM Amazon Channel'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'El Hombre Gris', 'calificacion': 7, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Pandemia: La guerra final', 'calificacion': 6, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Alerta roja', 'calificacion': 6.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Comedy', 'Crime', 'Thriller']}
# {'nombre': 'Guardianes de la Galaxia: Especial de las fiestas', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Science Fiction', 'Adventure']}
# {'nombre': 'Toy Story 2', 'calificacion': 7.6, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'La cenicienta', 'calificacion': 7, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Fantasy', 'Animation', 'Romance']}
# {'nombre': 'Monster High: La Película', 'calificacion': 7, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Family', 'Fantasy', 'Comedy', 'Adventure', 'Music', 'TV Movie']}
# {'nombre': 'El Escuadrón Suicida', 'calificacion': 7.6, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Comedy', 'Adventure']}
# {'nombre': 'Deadpool', 'calificacion': 7.6, 'streaming': ['Disney Plus', 'Star Plus'], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': '¡Scooby-Doo! Dulce o Travesura', 'calificacion': 7.3, 'streaming': [], 'genero': ['Adventure', 'Mystery', 'Comedy', 'Animation', 'Family']}
# {'nombre': 'Son Como Niños', 'calificacion': 6.4, 'streaming': ['Netflix', 'Star Plus', 'Paramount Plus', 'Claro video', 'HBO Max', 'Starz Play Amazon Channel', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Netflix basic with Ads', 'Lionsgate Plus'], 'genero': ['Comedy']}
# {'nombre': 'After: Almas Perdidas', 'calificacion': 7.1, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'El Conjuro', 'calificacion': 7.5, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Enola Holmes 2', 'calificacion': 7.6, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Adventure', 'Mystery', 'Comedy', 'Crime']}
# {'nombre': 'El despertar del diablo 2', 'calificacion': 7.6, 'streaming': [], 'genero': ['Horror', 'Comedy', 'Fantasy']}
# {'nombre': '¿Qué Pasó Ayer?', 'calificacion': 7.3, 'streaming': ['HBO Max'], 'genero': ['Comedy']}
# {'nombre': 'Paw Patrol: La Película', 'calificacion': 7.5, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Animation', 'Family', 'Adventure', 'Comedy']}
# {'nombre': 'Ant-Man: El hombre hormiga', 'calificacion': 7.1, 'streaming': ['Disney Plus'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'Piratas del Caribe: La Venganza de Salazar', 'calificacion': 6.6, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Fantasy']}
# {'nombre': 'Boleto de fuga', 'calificacion': 6.3, 'streaming': ['HBO Max'], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Pinocho', 'calificacion': 6.5, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Blood', 'calificacion': 5.8, 'streaming': [], 'genero': ['Thriller', 'Horror']}
# {'nombre': 'El meme maldito', 'calificacion': 5.3, 'streaming': ['Star Plus'], 'genero': ['Horror']}
# {'nombre': 'Matrix resurrecciones', 'calificacion': 6.5, 'streaming': ['HBO Max'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'El País de los Sueños', 'calificacion': 7.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Family', 'Fantasy']}
# {'nombre': 'La pasión de Cristo', 'calificacion': 7.5, 'streaming': ['Star Plus'], 'genero': ['Drama']}
# {'nombre': 'Invicto 4: La gran pelea', 'calificacion': 7.1, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Drama']}
# {'nombre': 'Quasi', 'calificacion': 4.9, 'streaming': ['Star Plus'], 'genero': ['Comedy']}
# {'nombre': 'Sonic: La Película', 'calificacion': 7.4, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Comedy', 'Family']}
# {'nombre': 'Deadpool 2', 'calificacion': 7.5, 'streaming': ['Disney Plus', 'Star Plus'], 'genero': ['Action', 'Comedy', 'Adventure']}
# {'nombre': 'Buscando a Nemo', 'calificacion': 7.8, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family']}
# {'nombre': 'Shrek tercero', 'calificacion': 6.3, 'streaming': [], 'genero': ['Fantasy', 'Adventure', 'Animation', 'Comedy', 'Family']}
# {'nombre': 'Un gran dinosaurio', 'calificacion': 6.7, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Animation', 'Family']}
# {'nombre': 'Medidas correctivas', 'calificacion': 5.2, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Thriller']}
# {'nombre': 'Groot se da un baño', 'calificacion': 7.1, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy', 'Science Fiction']}
# {'nombre': 'Bob Esponja: Al rescate', 'calificacion': 7.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Family', 'Animation', 'Fantasy', 'Adventure', 'Comedy']}
# {'nombre': 'El Hobbit: La Batalla De Los Cinco Ejércitos', 'calificacion': 7.3, 'streaming': ['Amazon Prime Video', 'MGM Amazon Channel'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Hay algo mal con los niños', 'calificacion': 6, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'El señor de los anillos: La comunidad del anillo', 'calificacion': 8.4, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'La princesa y el sapo', 'calificacion': 7.2, 'streaming': ['Disney Plus'], 'genero': ['Romance', 'Family', 'Animation']}
# {'nombre': 'Frozen 2', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Adventure', 'Comedy', 'Fantasy']}
# {'nombre': 'Soy inocente', 'calificacion': 6.6, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'Spider-Man: A través del Spider-Verso', 'calificacion': 0, 'streaming': [], 'genero': ['Animation', 'Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Iron Man 2', 'calificacion': 6.8, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Science Fiction']}
# {'nombre': 'Entre Hermanos', 'calificacion': 7.3, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Drama', 'Thriller', 'War']}
# {'nombre': 'Emancipación', 'calificacion': 8, 'streaming': ['Apple TV Plus'], 'genero': ['Drama']}
# {'nombre': 'El menú', 'calificacion': 7.2, 'streaming': ['Star Plus'], 'genero': ['Horror', 'Thriller', 'Comedy']}
# {'nombre': 'Wifi Ralph', 'calificacion': 7.2, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Comedy', 'Adventure']}
# {'nombre': 'Duna', 'calificacion': 7.8, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Science Fiction', 'Adventure']}
# {'nombre': 'Vida extra', 'calificacion': 5.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Comedy']}
# {'nombre': 'Barbie', 'calificacion': 0, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'Turno de día', 'calificacion': 6.9, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Fantasy', 'Horror', 'Comedy']}
# {'nombre': 'Miradas que Matan', 'calificacion': 4.6, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Tinker bell y La Bestia de Nunca Jamas', 'calificacion': 7.2, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Animation', 'Family']}
# {'nombre': 'Crepúsculo: Eclipse', 'calificacion': 6.2, 'streaming': ['Netflix', 'Netflix basic with Ads', 'Lionsgate Plus'], 'genero': ['Adventure', 'Fantasy', 'Drama', 'Romance']}
# {'nombre': 'Free Guy: Tomando el control', 'calificacion': 7.6, 'streaming': ['Star Plus'], 'genero': ['Comedy', 'Adventure', 'Science Fiction']}
# {'nombre': 'Los primeros pasos de Groot', 'calificacion': 7, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy', 'Science Fiction']}
# {'nombre': 'El Padrino', 'calificacion': 8.7, 'streaming': ['Netflix', 'Star Plus', 'Paramount Plus', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Netflix basic with Ads'], 'genero': ['Drama', 'Crime']}
# {'nombre': 'Guerra mundial Z', 'calificacion': 6.8, 'streaming': [], 'genero': ['Action', 'Drama', 'Horror', 'Science Fiction', 'Thriller']}
# {'nombre': 'El peso del talento', 'calificacion': 6.8, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Comedy', 'Crime']}
# {'nombre': 'Atrapados en el bosque', 'calificacion': 6, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Bienvenidos al Club', 'calificacion': 6.6, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy']}
# {'nombre': 'Doctor Strange: Hechicero supremo', 'calificacion': 7.4, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Frozen: Una aventura congelada', 'calificacion': 7.2, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Fantasy']}
# {'nombre': 'Guardianes De La Galaxia Vol. 2', 'calificacion': 7.6, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Science Fiction']}
# {'nombre': 'El Conjuro 2', 'calificacion': 7.3, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'El diario de Greg: Las reglas de Rodrick', 'calificacion': 7.1, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': "The King's Man: El Origen", 'calificacion': 6.8, 'streaming': ['Star Plus'], 'genero': ['Action', 'Adventure', 'Thriller', 'War', 'Mystery']}
# {'nombre': 'Yo creo', 'calificacion': 7, 'streaming': ['Amazon Prime Video'], 'genero': ['Family', 'Drama']}
# {'nombre': 'My Sailor, My Love', 'calificacion': 6, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Monstrous', 'calificacion': 6, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Zootopia', 'calificacion': 7.7, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Adventure', 'Family', 'Comedy']}
# {'nombre': 'El niño con el pijama de rayas', 'calificacion': 7.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['War', 'Drama', 'History']}
# {'nombre': 'Toda una vida en un año', 'calificacion': 8.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Ted 2', 'calificacion': 6.3, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Comedy', 'Fantasy']}
# {'nombre': 'Un extraño en nuestra cama', 'calificacion': 6.1, 'streaming': [], 'genero': ['Thriller', 'Mystery']}
# {'nombre': 'Jungle Cruise', 'calificacion': 7.5, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Titanes Del Pacífico', 'calificacion': 6.9, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Science Fiction', 'Adventure']}
# {'nombre': 'Black Widow', 'calificacion': 7.3, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Frank y Penelope Hasta que la Muerte nos Separe', 'calificacion': 7.7, 'streaming': [], 'genero': ['Thriller', 'Horror', 'Crime']}
# {'nombre': 'Soul', 'calificacion': 8.2, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy', 'Fantasy', 'Drama']}
# {'nombre': 'El Sorprendente Hombre Araña', 'calificacion': 6.7, 'streaming': ['Netflix', 'Amazon Prime Video', 'Disney Plus', 'Claro video', 'HBO Max', 'Netflix basic with Ads'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Spider-Man: De regreso a casa', 'calificacion': 7.4, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Adventure', 'Science Fiction', 'Drama']}
# {'nombre': 'Los juegos del hambre: Sinsajo - Parte 1', 'calificacion': 6.8, 'streaming': ['Amazon Prime Video', 'Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Science Fiction', 'Adventure', 'Thriller']}
# {'nombre': 'Hellraiser', 'calificacion': 6.4, 'streaming': [], 'genero': ['Horror', 'Mystery']}
# {'nombre': 'Madagascar: Algo salvaje un Ganso en las fiestas', 'calificacion': 6.3, 'streaming': [], 'genero': ['Animation', 'Comedy']}
# ...
# {'nombre': 'La hora decisiva', 'calificacion': 6.6, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Drama', 'History', 'Thriller']}
# {'nombre': 'El próximo viernes', 'calificacion': 6.5, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'Realmente amor', 'calificacion': 7.1, 'streaming': [], 'genero': ['Comedy', 'Romance', 'Drama']}
# {'nombre': 'Campamento en el fin del mundo', 'calificacion': 6, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Science Fiction', 'Adventure', 'Action', 'Comedy']}
# {'nombre': 'Menace II Society', 'calificacion': 7.5, 'streaming': [], 'genero': ['Drama', 'Crime']}
# {'nombre': 'Sub Rosa', 'calificacion': 6.3, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Ki Main Jhoot Boleya', 'calificacion': 2, 'streaming': [], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Ma', 'calificacion': 5.8, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Comando Kill', 'calificacion': 5.5, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Horror', 'Science Fiction']}
# {'nombre': 'El Cocodrilo vs Anaconda', 'calificacion': 5.2, 'streaming': [], 'genero': ['Action', 'Horror']}
# {'nombre': 'Erax', 'calificacion': 4.9, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Mystery', 'Family']}
# {'nombre': 'Rounders', 'calificacion': 7, 'streaming': [], 'genero': ['Drama', 'Crime']}
# {'nombre': 'The Exorcism of Molly Hartley', 'calificacion': 5, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Annapolis', 'calificacion': 6.6, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Action']}
# {'nombre': 'Doble riesgo', 'calificacion': 6.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Thriller', 'Crime', 'Mystery', 'Drama']}
# {'nombre': 'Anticristo', 'calificacion': 6.7, 'streaming': [], 'genero': ['Drama', 'Horror', 'Thriller']}
# {'nombre': 'Celda', 'calificacion': 4.7, 'streaming': ['Claro video'], 'genero': ['Horror', 'Science Fiction', 'Thriller']}
# {'nombre': 'Crossing Paths', 'calificacion': 0, 'streaming': [], 'genero': []}
# {'nombre': 'Travieso: De la mansión a la calle', 'calificacion': 6.7, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Adventure', 'Family', 'Comedy', 'Music']}
# {'nombre': 'The Lincoln Lawyer', 'calificacion': 7.2, 'streaming': ['Amazon Prime Video'], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'El camino de regreso', 'calificacion': 6.6, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Drama']}
# {'nombre': 'Navidad contigo', 'calificacion': 5.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'El infierno de Dante', 'calificacion': 7, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Action', 'Adventure', 'Animation', 'Horror']}
# {'nombre': 'Transcendence: Identidad virtual', 'calificacion': 6, 'streaming': [], 'genero': ['Thriller', 'Science Fiction', 'Drama', 'Mystery']}
# {'nombre': 'Entergalactic', 'calificacion': 7.7, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Comedy', 'Romance', 'Music']}
# {'nombre': 'Atentado en París', 'calificacion': 6.3, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Un jefe en pañales: ¡Atrapa al bebé!', 'calificacion': 6.5, 'streaming': ['Netflix'], 'genero': ['Comedy', 'Family', 'Animation']}
# {'nombre': 'Los niños del maíz', 'calificacion': 5.8, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Amy', 'calificacion': 7.6, 'streaming': [], 'genero': ['Documentary', 'Music']}
# {'nombre': 'Universo en Fantasía', 'calificacion': 6.5, 'streaming': [], 'genero': ['Animation', 'Science Fiction', 'Adventure', 'Fantasy', 'Music']}
# {'nombre': 'El Hijo De Pie Grande', 'calificacion': 6.6, 'streaming': [], 'genero': ['Family', 'Animation', 'Comedy']}
# {'nombre': 'Proyecto Florida', 'calificacion': 7.4, 'streaming': ['HBO Max'], 'genero': ['Drama']}
# {'nombre': 'El duende maldito 5 en el barrio', 'calificacion': 5, 'streaming': [], 'genero': ['Horror', 'Comedy']}
# {'nombre': 'Tango y Cash', 'calificacion': 6.4, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Comedy', 'Thriller']}
# {'nombre': 'Sombras en el bosque', 'calificacion': 5.8, 'streaming': ['Amazon Prime Video'], 'genero': ['Fantasy', 'Horror']}
# {'nombre': 'Sé lo que hicieron el verano pasado', 'calificacion': 5.9, 'streaming': [], 'genero': ['Horror', 'Thriller', 'Mystery']}
# {'nombre': 'El guerrero solitario', 'calificacion': 6.8, 'streaming': [], 'genero': ['War', 'Action', 'Comedy', 'Drama']}
# {'nombre': 'Ray', 'calificacion': 7.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Music']}
# {'nombre': 'El huésped', 'calificacion': 6.6, 'streaming': ['Amazon Prime Video'], 'genero': ['Mystery', 'Thriller', 'Action']}
# {'nombre': 'Ronin', 'calificacion': 6.9, 'streaming': ['Amazon Prime Video', 'MGM Amazon Channel'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'La huida', 'calificacion': 6.4, 'streaming': ['HBO Max'], 'genero': ['Action', 'Thriller', 'Comedy', 'Crime']}
# {'nombre': 'Un día más para morir', 'calificacion': 6.9, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Thriller']}
# {'nombre': 'Inmortales (Immortals)', 'calificacion': 5.9, 'streaming': ['Amazon Prime Video'], 'genero': ['Fantasy', 'Action', 'Drama']}
# {'nombre': 'Estafadoras en oferta', 'calificacion': 6.5, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Comedy', 'Crime']}
# {'nombre': 'Loca Academia de Pilotos 2', 'calificacion': 6.5, 'streaming': ['Star Plus'], 'genero': ['Action', 'Comedy', 'War']}
# {'nombre': 'Radio', 'calificacion': 7.2, 'streaming': ['HBO Max'], 'genero': ['Drama']}
# {'nombre': 'KSI: In Real Life', 'calificacion': 6.3, 'streaming': ['Amazon Prime Video'], 'genero': ['Documentary']}
# {'nombre': 'En el bosque sobrevive', 'calificacion': 5.8, 'streaming': ['Amazon Prime Video'], 'genero': ['Thriller', 'Drama', 'Horror']}
# {'nombre': 'Rescate en la Antártica', 'calificacion': 7, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Drama', 'Family']}
# {'nombre': 'Romeo y Julieta', 'calificacion': 7.4, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'La emboscada', 'calificacion': 6.2, 'streaming': ['Star Plus', 'HBO Max'], 'genero': ['Romance', 'Drama', 'Mystery']}
# {'nombre': 'El Avispón Verde', 'calificacion': 5.6, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Action', 'Crime', 'Comedy']}
# {'nombre': 'Sex and Death 101', 'calificacion': 6.1, 'streaming': [], 'genero': ['Comedy', 'Romance', 'Drama']}
# {'nombre': 'Del crepúsculo al amanecer 2: Terror en Texas', 'calificacion': 4.6, 'streaming': [], 'genero': ['Crime', 'Action', 'Horror', 'Thriller']}
# {'nombre': 'Kingdom of the Planet of the Apes', 'calificacion': 0, 'streaming': [], 'genero': ['Action', 'Science Fiction']}
# {'nombre': 'Ariana Grande: Excuse me, I love you', 'calificacion': 8.2, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Music', 'Documentary']}
# {'nombre': 'King Kong', 'calificacion': 7.6, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy', 'Horror']}
# {'nombre': 'Noche infernal', 'calificacion': 6.1, 'streaming': ['HBO Max'], 'genero': ['Thriller', 'Crime', 'Action']}
# {'nombre': 'Sueños de Marte', 'calificacion': 7, 'streaming': [], 'genero': ['Comedy', 'Romance', 'Science Fiction']}
# {'nombre': 'Magnum 44', 'calificacion': 7.1, 'streaming': ['HBO Max'], 'genero': ['Drama', 'Crime', 'Action']}
# {'nombre': 'Guns Akimbo', 'calificacion': 6.5, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Action']}
# {'nombre': 'El poder del talismán', 'calificacion': 5.6, 'streaming': ['Star Plus'], 'genero': ['Thriller', 'Fantasy', 'Action', 'Comedy']}
# {'nombre': 'Hooligans - Defiende a los tuyos', 'calificacion': 7.3, 'streaming': [], 'genero': ['Crime', 'Drama']}
# {'nombre': 'Malcolm y Marie', 'calificacion': 7.1, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Locos por las nueces 2', 'calificacion': 5.9, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Family', 'Adventure', 'Comedy']}
# {'nombre': 'El Coleccionista 2', 'calificacion': 6.3, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Las Tortugas Ninja III: Viaje al pasado', 'calificacion': 5.4, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Adventure', 'Comedy', 'Family', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Los Beverly Ricos', 'calificacion': 6.2, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'Intersect', 'calificacion': 5.6, 'streaming': [], 'genero': ['Horror', 'Science Fiction', 'Thriller']}
# {'nombre': 'The Girl Next Door', 'calificacion': 6.7, 'streaming': [], 'genero': ['Thriller', 'Crime', 'Drama', 'Horror']}
# {'nombre': 'Miss Simpatía 2: Armada y Fabulosa', 'calificacion': 5.7, 'streaming': ['HBO Max'], 'genero': ['Action', 'Comedy']}
# {'nombre': 'Hasta el Límite', 'calificacion': 6.4, 'streaming': ['Star Plus'], 'genero': ['Action', 'Drama']}
# {'nombre': 'Un Zoologico en Casa', 'calificacion': 6.8, 'streaming': ['Disney Plus'], 'genero': ['Drama', 'Comedy', 'Family']}
# {'nombre': 'The Grissom Gang', 'calificacion': 6.6, 'streaming': [], 'genero': ['Drama', 'Action', 'Thriller', 'Crime']}
# {'nombre': 'Discarnate', 'calificacion': 5.4, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Fargo, secuestro voluntario', 'calificacion': 7.9, 'streaming': ['MGM Amazon Channel'], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Virgen a los 40', 'calificacion': 6.4, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Romance']}
# {'nombre': 'Romance en Verona (Love in the Villa)', 'calificacion': 6, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Peter Pan', 'calificacion': 6, 'streaming': ['HBO Max'], 'genero': ['Fantasy', 'Adventure', 'Family', 'Action']}
# {'nombre': 'El Juez', 'calificacion': 5.8, 'streaming': [], 'genero': ['Science Fiction']}
# {'nombre': 'Terror en la niebla', 'calificacion': 4.5, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Soldado anónimo 3: El asedio', 'calificacion': 6.3, 'streaming': [], 'genero': ['War', 'Action', 'Drama']}
# {'nombre': 'Tarde de Perros', 'calificacion': 7.8, 'streaming': ['HBO Max'], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Bullitt', 'calificacion': 7.1, 'streaming': ['HBO Max'], 'genero': ['Action', 'Crime', 'Drama', 'Thriller']}
# {'nombre': 'L.E.T.H.A.L. Ladies: Return to Savage Beach', 'calificacion': 6.3, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'El escuadrón del crimen', 'calificacion': 6.2, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Crime', 'Drama', 'Thriller']}
# {'nombre': 'Hot Fuzz: Super policías', 'calificacion': 7.5, 'streaming': ['Netflix', 'Starz Play Amazon Channel', 'Netflix basic with Ads', 'Lionsgate Plus'], 'genero': ['Crime', 'Action', 'Comedy']}
# {'nombre': 'El Ritmo de la Venganza', 'calificacion': 5.6, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Un equipo muy especial', 'calificacion': 7.2, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'The Zorchavis', 'calificacion': 0, 'streaming': [], 'genero': ['Fantasy', 'Drama']}
# {'nombre': 'Hechizo de amor', 'calificacion': 6.7, 'streaming': ['HBO Max'], 'genero': ['Romance', 'Comedy', 'Fantasy']}
# {'nombre': 'Seduciendo a un extraño', 'calificacion': 5.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Thriller', 'Crime', 'Mystery']}
# {'nombre': 'Miedo a la Lluvia', 'calificacion': 7.1, 'streaming': ['Amazon Prime Video'], 'genero': ['Thriller', 'Horror', 'Drama']}
# {'nombre': 'Junto a ti (Drive Me Crazy)', 'calificacion': 6.6, 'streaming': [], 'genero': ['Romance', 'Comedy', 'Drama']}
# {'nombre': 'The Diplomat', 'calificacion': 5.7, 'streaming': [], 'genero': ['Action', 'Crime', 'Drama', 'Mystery', 'Thriller']}
# {'nombre': 'El Aviador', 'calificacion': 7.2, 'streaming': [], 'genero': ['Drama']}
# {'nombre': 'Expression', 'calificacion': 0, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Vice: Venganza Mortal', 'calificacion': 4.4, 'streaming': ['Amazon Prime Video', 'Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel'], 'genero': ['Thriller', 'Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'Aventuras de la Liga de la Justicia: Atrapados en el Tiempo', 'calificacion': 6.7, 'streaming': ['HBO Max'], 'genero': ['Family', 'Animation', 'Action', 'Science Fiction']}
# {'nombre': 'Captain America', 'calificacion': 4.5, 'streaming': [], 'genero': ['Action', 'Adventure', 'Science Fiction', 'War']}
# {'nombre': 'Camino a la perdicion', 'calificacion': 7.4, 'streaming': ['Star Plus'], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Lazos perversos', 'calificacion': 6.7, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Horror', 'Thriller']}
# {'nombre': 'La Maldición de las Hermanas', 'calificacion': 6.5, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'El Contador de Cartas', 'calificacion': 6.2, 'streaming': ['HBO Max'], 'genero': ['Crime', 'Thriller', 'Drama']}
# {'nombre': 'Tribal: Get Out Alive', 'calificacion': 3.6, 'streaming': [], 'genero': ['Action', 'Horror', 'Thriller']}
# {'nombre': 'Cuando los hermanos se encuentran', 'calificacion': 7.8, 'streaming': ['Amazon Prime Video', 'MGM Amazon Channel'], 'genero': ['Drama']}
# {'nombre': 'Yo, Tonya', 'calificacion': 7.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Drama']}
# {'nombre': 'La venganza', 'calificacion': 6.6, 'streaming': [], 'genero': ['Romance', 'Thriller', 'Drama']}
# {'nombre': "Ed, Edd n Eddy's Big Picture Show", 'calificacion': 7.3, 'streaming': [], 'genero': ['Comedy', 'Animation', 'Adventure', 'TV Movie']}
# {'nombre': 'Cielos tenebrosos', 'calificacion': 6.3, 'streaming': ['Amazon Prime Video', 'Paramount Plus', 'Paramount+ Amazon Channel'], 'genero': ['Science Fiction', 'Thriller', 'Horror']}
# {'nombre': 'Cuando Harry conoció a Sally', 'calificacion': 7.4, 'streaming': ['Amazon Prime Video', 'MGM Amazon Channel'], 'genero': ['Comedy', 'Romance', 'Drama']}
# {'nombre': 'La casa de cristal', 'calificacion': 5.9, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Drama', 'Thriller']}
# {'nombre': 'Terror profundo', 'calificacion': 6.2, 'streaming': [], 'genero': ['Adventure', 'Action', 'Horror', 'Science Fiction']}
# {'nombre': 'Muertos de miedo', 'calificacion': 6.9, 'streaming': [], 'genero': ['Horror', 'Comedy']}
# {'nombre': 'Llamas de venganza', 'calificacion': 5.8, 'streaming': ['HBO Max'], 'genero': ['Science Fiction', 'Thriller', 'Horror']}
# {'nombre': 'For Years to Come', 'calificacion': 0, 'streaming': [], 'genero': []}
# {'nombre': 'The Sand', 'calificacion': 5.3, 'streaming': [], 'genero': ['Horror', 'Science Fiction', 'Comedy']}
# {'nombre': 'Ember: La ciudad perdida', 'calificacion': 6.3, 'streaming': [], 'genero': ['Adventure', 'Family', 'Fantasy']}
# {'nombre': 'Cyborg', 'calificacion': 5.6, 'streaming': ['MGM Amazon Channel'], 'genero': ['Science Fiction', 'Action', 'Thriller', 'Adventure']}
# {'nombre': 'Howards End', 'calificacion': 7, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'La familia de mi novia', 'calificacion': 6.7, 'streaming': ['Star Plus'], 'genero': ['Comedy', 'Romance']}
# {'nombre': 'Los tentáculos de las Bermudas', 'calificacion': 4.1, 'streaming': ['Amazon Prime Video'], 'genero': ['Science Fiction']}
# {'nombre': '¡ScoobyDoo! y el monstruo de México', 'calificacion': 7.4, 'streaming': [], 'genero': ['Animation', 'Comedy', 'Family', 'Mystery']}
# {'nombre': 'Soltero en Navidad', 'calificacion': 6.5, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Isla de perros', 'calificacion': 7.9, 'streaming': ['Star Plus'], 'genero': ['Adventure', 'Comedy', 'Animation']}
# {'nombre': 'Aliados', 'calificacion': 6.8, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Drama', 'War', 'Romance', 'Thriller']}

# %%
movies_json = json.dumps(movies_data)

# %%
with open('movies.json', 'w') as file:
    file.write(movies_json)
