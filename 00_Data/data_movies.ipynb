# %%
import requests
import json

# Llave de API de The Movie DB
api_key = "a88fba1e1f31a7d6a5069ba558f0b210"

# URL base para la API de The Movie DB
base_url = "https://api.themoviedb.org/3/"

# Endpoint para obtener todas las películas
movies_endpoint = "discover/movie"

# Parámetros para la consulta a la API
params = {
    "api_key": api_key,
    "sort_by": "popularity.desc",
    "language": "es-MX",
    "with_original_language": "en",
    "timezone": "America/Mexico_City",
    "with_watch_monetization_types": "flatrate",
    "page": 1,
    "include_adult": False
}

# Lista vacía para almacenar los datos de las películas
movies_data = []

# Loop para recorrer todas las páginas de resultados
while params["page"] <= 200:
    # Hacer la petición GET a la API
    response = requests.get(base_url + movies_endpoint, params=params)
    # Convertir la respuesta a JSON
    response_json = json.loads(response.content)
    # Obtener los resultados de la consulta
    results = response_json["results"]
    # Si no hay más resultados, salir del loop
    if not results:
        break
    # Loop para procesar los resultados de la página actual
    for result in results:
        # Obtener los datos de la película
        movie_data = {
            "nombre": result["title"],
            "calificacion": result["vote_average"],
            "vistas": result["popularity"],
            "streaming": []
        }
        # Obtener los IDs de los géneros de la película
        genre_ids = result['genre_ids']
        # Obtener los nombres de los géneros correspondientes a los IDs de género
        genre_names = []
        for genre_id in genre_ids:
            genre_url = f'https://api.themoviedb.org/3/genre/movie/list?api_key={api_key}'
            genre_response = requests.get(genre_url)
            genre_data = genre_response.json()
            genre_names.append([genre['name'] for genre in genre_data['genres'] if genre['id'] == genre_id][0])
        movie_data['genero'] = genre_names
        # Obtener los datos de transmisión de la película
        streaming_endpoint = f"movie/{result['id']}/watch/providers"
        streaming_params = {
            "api_key": api_key,
            "region": "MX"
        }
        streaming_response = requests.get(base_url + streaming_endpoint, params=streaming_params)
        streaming_response_json = json.loads(streaming_response.content)
        if "results" in streaming_response_json and "MX" in streaming_response_json["results"]:
            results_mx = streaming_response_json["results"]["MX"]
            if "flatrate" in results_mx:
                for provider in results_mx["flatrate"]:
                    movie_data["streaming"].append(provider["provider_name"])
        # Agregar los datos de la película a la lista
        movies_data.append(movie_data)
    # Incrementar el número de página para la siguiente consulta
    params["page"] += 1

# Va a imprimir titulo, genero, calificacion y vistas
for movie in movies_data:
    print(movie)
# Out:
# {'nombre': 'Ant-Man and the Wasp: Quantumania', 'calificacion': 6.5, 'vistas': 10446.465, 'streaming': [], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Super Mario Bros. La película', 'calificacion': 7.5, 'vistas': 8282.211, 'streaming': [], 'genero': ['Animation', 'Adventure', 'Family', 'Fantasy', 'Comedy']}
# {'nombre': '¡Shazam! La furia de los dioses', 'calificacion': 6.8, 'vistas': 4790.147, 'streaming': [], 'genero': ['Action', 'Comedy', 'Fantasy']}
# {'nombre': 'Avatar: El camino del agua', 'calificacion': 7.7, 'vistas': 3900.586, 'streaming': [], 'genero': ['Science Fiction', 'Adventure', 'Action']}
# {'nombre': 'Creed III', 'calificacion': 7.3, 'vistas': 3219.774, 'streaming': [], 'genero': ['Drama', 'Action']}
# {'nombre': 'Evil Dead: El despertar', 'calificacion': 7, 'vistas': 2291.491, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Misterio a la vista', 'calificacion': 6.6, 'vistas': 2117.072, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Mystery', 'Action']}
# {'nombre': 'Siete reyes deben morir', 'calificacion': 7.4, 'vistas': 3329.466, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Adventure', 'History', 'Drama', 'War']}
# {'nombre': '65: Al borde de la extinción', 'calificacion': 6.3, 'vistas': 1325.004, 'streaming': [], 'genero': ['Science Fiction', 'Adventure', 'Thriller', 'Action']}
# {'nombre': 'John Wick 4', 'calificacion': 8, 'vistas': 1444.362, 'streaming': [], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'Oso intoxicado', 'calificacion': 6.4, 'vistas': 1332.34, 'streaming': [], 'genero': ['Thriller', 'Comedy', 'Crime']}
# {'nombre': 'Gato con Botas: El último deseo', 'calificacion': 8.3, 'vistas': 1525.433, 'streaming': [], 'genero': ['Animation', 'Family', 'Fantasy', 'Adventure', 'Comedy', 'Drama']}
# {'nombre': 'El exorcista del papa', 'calificacion': 6.6, 'vistas': 1229.734, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Gangs of Lagos', 'calificacion': 5.8, 'vistas': 1243.649, 'streaming': ['Amazon Prime Video'], 'genero': ['Crime']}
# {'nombre': 'Cazador de tormentas', 'calificacion': 6.4, 'vistas': 1052.219, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Chupa', 'calificacion': 6.5, 'vistas': 961.308, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Adventure', 'Fantasy', 'Family']}
# {'nombre': 'Attack on Titan', 'calificacion': 6.1, 'vistas': 988.692, 'streaming': [], 'genero': ['Action', 'Science Fiction']}
# {'nombre': 'Pantera Negra: Wakanda por siempre', 'calificacion': 7.3, 'vistas': 854.059, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Winnie the Pooh: Sangre y Miel', 'calificacion': 5.8, 'vistas': 813.708, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Black Adam', 'calificacion': 7.1, 'vistas': 766.772, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Science Fiction', 'Fantasy']}
# {'nombre': 'LA CONSPIRACIÓN DEL DIABLO', 'calificacion': 6.3, 'vistas': 722.341, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'The Park', 'calificacion': 5.8, 'vistas': 774.951, 'streaming': [], 'genero': ['Action', 'Drama', 'Horror', 'Science Fiction', 'Thriller']}
# {'nombre': 'Alerta extrema', 'calificacion': 6.9, 'vistas': 691.213, 'streaming': [], 'genero': ['Action', 'Adventure', 'Thriller']}
# {'nombre': 'Rey del anillo: La historia de Jem Belcher', 'calificacion': 6.2, 'vistas': 690.417, 'streaming': [], 'genero': ['Drama', 'History']}
# {'nombre': 'Llaman a la puerta', 'calificacion': 6.4, 'vistas': 591.933, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Las aventuras de Maurice', 'calificacion': 7, 'vistas': 576.862, 'streaming': [], 'genero': ['Animation', 'Adventure', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'La Resurrección de la Momia', 'calificacion': 6.2, 'vistas': 538.012, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'M3GAN', 'calificacion': 7.4, 'vistas': 633.892, 'streaming': [], 'genero': ['Science Fiction', 'Horror', 'Comedy']}
# {'nombre': 'Bodas de plomo', 'calificacion': 6.3, 'vistas': 515.031, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Comedy', 'Romance']}
# {'nombre': 'Adrenaline', 'calificacion': 4, 'vistas': 906.975, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Posesión Infernal', 'calificacion': 6.5, 'vistas': 458.557, 'streaming': ['HBO Max'], 'genero': ['Horror']}
# {'nombre': 'La luz del diablo', 'calificacion': 7.1, 'vistas': 400.262, 'streaming': ['Amazon Prime Video'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Rápidos y furiosos X', 'calificacion': 0, 'vistas': 504.247, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Hart: Duro de entrenar', 'calificacion': 6.1, 'vistas': 394.94, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Comedy', 'Thriller']}
# {'nombre': 'Tiburones en La Luna', 'calificacion': 5.3, 'vistas': 450.098, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Thriller', 'Horror']}
# {'nombre': 'Vértigo', 'calificacion': 7.3, 'vistas': 429.862, 'streaming': ['Amazon Prime Video'], 'genero': ['Thriller']}
# {'nombre': 'LA CONSAGRACIÓN', 'calificacion': 6.5, 'vistas': 387.177, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Batman: La Perdición que llegó a Ciudad Gótica', 'calificacion': 6.5, 'vistas': 439.754, 'streaming': [], 'genero': ['Animation', 'Fantasy', 'Horror', 'Action', 'Mystery']}
# {'nombre': 'Marcel, el caracol con zapatos', 'calificacion': 7.8, 'vistas': 699.268, 'streaming': [], 'genero': ['Animation', 'Comedy', 'Family', 'Drama', 'Adventure']}
# {'nombre': 'La elefanta del Mago', 'calificacion': 7.2, 'vistas': 369.937, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Adventure', 'Family', 'Fantasy']}
# {'nombre': 'El clímax del millón: La historia de Pornhub', 'calificacion': 5.7, 'vistas': 432.953, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Documentary']}
# {'nombre': 'H.P. Lovecraft’s Witch House', 'calificacion': 5.8, 'vistas': 341.135, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'John Wick: Chapter 5', 'calificacion': 0, 'vistas': 378.947, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Scream 6', 'calificacion': 7.3, 'vistas': 435.672, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Thor: Amor y Trueno', 'calificacion': 6.6, 'vistas': 341.767, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Action', 'Comedy']}
# {'nombre': 'Spider-Man: Sin camino a casa', 'calificacion': 8, 'vistas': 347.55, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Matilda, de Roald Dahl: El musical', 'calificacion': 6.8, 'vistas': 342.267, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Family', 'Comedy', 'Fantasy']}
# {'nombre': '¿Y qué tendrá que ver el amor?', 'calificacion': 6.5, 'vistas': 275.484, 'streaming': [], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Legión de superhéroes', 'calificacion': 6.3, 'vistas': 309.818, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Action', 'Science Fiction']}
# {'nombre': 'Encanto en El Hollywood Bowl', 'calificacion': 7.1, 'vistas': 313.156, 'streaming': ['Disney Plus'], 'genero': ['Music']}
# {'nombre': 'Black Warrant', 'calificacion': 5.6, 'vistas': 329.303, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Top Gun: Maverick', 'calificacion': 8.3, 'vistas': 352.06, 'streaming': ['Star Plus', 'Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Action', 'Drama']}
# {'nombre': 'El atracador perfecto', 'calificacion': 6.1, 'vistas': 291.844, 'streaming': [], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Geo-Tormenta', 'calificacion': 6.1, 'vistas': 291.895, 'streaming': ['HBO Max'], 'genero': ['Action', 'Science Fiction', 'Thriller']}
# {'nombre': 'Sonic 2: La Película', 'calificacion': 7.6, 'vistas': 321, 'streaming': ['Star Plus'], 'genero': ['Action', 'Adventure', 'Family', 'Comedy']}
# {'nombre': 'Sick', 'calificacion': 6.3, 'vistas': 286.898, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Little Dixie', 'calificacion': 6, 'vistas': 301.253, 'streaming': [], 'genero': ['Thriller', 'Action', 'Drama', 'Crime']}
# {'nombre': 'Transfusion', 'calificacion': 6.3, 'vistas': 366.671, 'streaming': [], 'genero': ['Crime', 'Thriller', 'Drama']}
# {'nombre': 'Los Simpson cononcen a los Bocelli en Feliz Navidad', 'calificacion': 5.2, 'vistas': 304.295, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy']}
# {'nombre': 'John Wick 2: Un Nuevo Día Para Matar', 'calificacion': 7.3, 'vistas': 307.559, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'La ballena', 'calificacion': 8.1, 'vistas': 282.697, 'streaming': [], 'genero': ['Drama']}
# {'nombre': 'Jurassic World Dominio', 'calificacion': 6.9, 'vistas': 284.909, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Action', 'Science Fiction']}
# {'nombre': 'TERRIFIER 2: EL PAYASO SINIESTRO', 'calificacion': 6.9, 'vistas': 274.493, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'El asesino perfecto', 'calificacion': 7.4, 'vistas': 294.557, 'streaming': [], 'genero': ['Action', 'Crime', 'Drama', 'Thriller']}
# {'nombre': 'Calabozos & Dragones: Honor entre ladrones', 'calificacion': 7.4, 'vistas': 299.633, 'streaming': [], 'genero': ['Adventure', 'Fantasy', 'Comedy']}
# {'nombre': 'Power Rangers: Ayer, hoy y siempre', 'calificacion': 7, 'vistas': 271.308, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Science Fiction', 'Fantasy']}
# {'nombre': 'Sonríe', 'calificacion': 6.8, 'vistas': 257.629, 'streaming': ['Star Plus', 'Paramount Plus', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'La Mujer Rey', 'calificacion': 7.8, 'vistas': 286.069, 'streaming': [], 'genero': ['Action', 'Drama', 'History']}
# {'nombre': 'Depredador: La presa', 'calificacion': 7.8, 'vistas': 284.448, 'streaming': ['Star Plus'], 'genero': ['Thriller', 'Action', 'Science Fiction']}
# {'nombre': 'Super Mario Bros.', 'calificacion': 4.3, 'vistas': 251.835, 'streaming': [], 'genero': ['Adventure', 'Fantasy', 'Comedy', 'Family', 'Science Fiction']}
# {'nombre': 'Hex', 'calificacion': 6.1, 'vistas': 251.801, 'streaming': [], 'genero': ['Action', 'Horror', 'Thriller']}
# {'nombre': 'Ghosteado', 'calificacion': 7.3, 'vistas': 442.736, 'streaming': ['Apple TV Plus'], 'genero': ['Romance', 'Action', 'Comedy']}
# {'nombre': 'R.I.P.D. 2: La rebelión de los condenados', 'calificacion': 6.6, 'vistas': 261.528, 'streaming': [], 'genero': ['Action', 'Comedy', 'Fantasy', 'Crime']}
# {'nombre': 'Historia de honor', 'calificacion': 7.3, 'vistas': 251.196, 'streaming': ['Amazon Prime Video'], 'genero': ['War', 'History', 'Drama']}
# {'nombre': 'John Wick 3: Parabellum', 'calificacion': 7.4, 'vistas': 264.573, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'Doctor Strange en el multiverso de la locura', 'calificacion': 7.4, 'vistas': 263.556, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Action', 'Adventure']}
# {'nombre': 'Pinocho de Guillermo del Toro', 'calificacion': 8.2, 'vistas': 248.927, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Fantasy', 'Drama', 'Music']}
# {'nombre': 'Lord of the Streets', 'calificacion': 5.4, 'vistas': 260.536, 'streaming': [], 'genero': ['Action']}
# {'nombre': 'Medieval', 'calificacion': 7.2, 'vistas': 248.783, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Drama', 'History']}
# {'nombre': 'Un jefe en pañales: Especial de Navidad', 'calificacion': 6.8, 'vistas': 244.076, 'streaming': ['Netflix'], 'genero': ['Animation', 'Family', 'Adventure']}
# {'nombre': 'Avatar', 'calificacion': 7.6, 'vistas': 240.324, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Luck', 'calificacion': 7.9, 'vistas': 248.963, 'streaming': ['Apple TV Plus'], 'genero': ['Animation', 'Adventure', 'Comedy', 'Fantasy']}
# {'nombre': 'Batman', 'calificacion': 7.7, 'vistas': 237.771, 'streaming': ['HBO Max'], 'genero': ['Crime', 'Mystery', 'Thriller']}
# {'nombre': 'Minions: Nace un villano', 'calificacion': 7.4, 'vistas': 217.632, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'Las crónicas de Narnia: El león, la bruja y el ropero', 'calificacion': 7.1, 'vistas': 274.362, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Family', 'Fantasy']}
# {'nombre': 'Scream 5', 'calificacion': 6.7, 'vistas': 348.297, 'streaming': ['Star Plus'], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Vida extra', 'calificacion': 5.3, 'vistas': 267.892, 'streaming': ['Amazon Prime Video'], 'genero': ['Comedy']}
# {'nombre': 'Géminis: El planeta oscuro', 'calificacion': 5.8, 'vistas': 222.718, 'streaming': [], 'genero': ['Science Fiction', 'Horror']}
# {'nombre': 'Godzilla vs Kong', 'calificacion': 7.7, 'vistas': 216.141, 'streaming': ['Amazon Prime Video', 'HBO Max', 'DIRECTV GO'], 'genero': ['Action', 'Fantasy', 'Science Fiction']}
# {'nombre': 'El despertar del diablo', 'calificacion': 7.3, 'vistas': 222.235, 'streaming': ['HBO Max'], 'genero': ['Horror']}
# {'nombre': 'Red', 'calificacion': 7.5, 'vistas': 223.026, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Comedy', 'Fantasy']}
# {'nombre': 'El Exorcismo de Dios', 'calificacion': 7.2, 'vistas': 195.477, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'La reencarnación del demonio', 'calificacion': 5.8, 'vistas': 205.007, 'streaming': [], 'genero': ['Horror', 'Thriller', 'Mystery']}
# {'nombre': 'Barbie Skipper Y La Gran Aventura Como Niñera', 'calificacion': 7.3, 'vistas': 223.04, 'streaming': [], 'genero': ['Family', 'Animation']}
# {'nombre': 'Un vecino gruñón', 'calificacion': 7.9, 'vistas': 207.063, 'streaming': [], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'Encanto', 'calificacion': 7.6, 'vistas': 221.183, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Un extraño en nuestra cama', 'calificacion': 6.1, 'vistas': 321.638, 'streaming': [], 'genero': ['Thriller', 'Mystery']}
# {'nombre': 'Adicción perfecta', 'calificacion': 6.7, 'vistas': 200.904, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Romance', 'Action']}
# {'nombre': 'Noche sin paz', 'calificacion': 7.6, 'vistas': 245.448, 'streaming': [], 'genero': ['Action', 'Comedy', 'Crime', 'Thriller']}
# {'nombre': 'Detective Knight: Independencia', 'calificacion': 5.6, 'vistas': 223.72, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Efecto nocebo', 'calificacion': 6.2, 'vistas': 212.229, 'streaming': [], 'genero': ['Mystery', 'Thriller', 'Horror']}
# {'nombre': 'Avengers: Infinity War', 'calificacion': 8.3, 'vistas': 234.53, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Science Fiction']}
# {'nombre': 'Crimen imperfecto', 'calificacion': 4.3, 'vistas': 216.668, 'streaming': [], 'genero': ['Thriller', 'Crime']}
# {'nombre': 'Guardianes de la Galaxia volumen 3', 'calificacion': 0, 'vistas': 249.137, 'streaming': [], 'genero': ['Science Fiction', 'Adventure', 'Action']}
# {'nombre': 'A Good Person', 'calificacion': 7, 'vistas': 168.071, 'streaming': [], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'No hay santos', 'calificacion': 5.3, 'vistas': 194.955, 'streaming': [], 'genero': ['Action', 'Mystery', 'Thriller']}
# {'nombre': 'Venom: Carnage Liberado', 'calificacion': 6.9, 'vistas': 182.296, 'streaming': ['HBO Max'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'Tren bala', 'calificacion': 7.5, 'vistas': 191.158, 'streaming': ['HBO Max'], 'genero': ['Action', 'Comedy', 'Thriller']}
# {'nombre': 'Lilo, Lilo, cocodrilo', 'calificacion': 7.4, 'vistas': 191.109, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Family', 'Music']}
# {'nombre': 'Ofrenda Al Demonio', 'calificacion': 5.7, 'vistas': 176.176, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Un mundo extraño', 'calificacion': 6.5, 'vistas': 193.502, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Science Fiction']}
# {'nombre': 'Bestia', 'calificacion': 6.8, 'vistas': 190.392, 'streaming': ['HBO Max'], 'genero': ['Thriller', 'Action', 'Horror', 'Adventure']}
# {'nombre': 'La espada de los 47 Ronin', 'calificacion': 6.6, 'vistas': 201.708, 'streaming': [], 'genero': ['Action', 'Drama', 'Fantasy', 'Thriller']}
# {'nombre': 'El rio de la ira', 'calificacion': 6.6, 'vistas': 181.123, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Hotel Transylvania 4: Transformanía', 'calificacion': 7.1, 'vistas': 191.077, 'streaming': ['Amazon Prime Video'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy', 'Adventure']}
# {'nombre': 'John Wick 1: Otro Día Para Matar', 'calificacion': 7.4, 'vistas': 184.077, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Shrek', 'calificacion': 7.7, 'vistas': 195.755, 'streaming': ['Amazon Prime Video'], 'genero': ['Animation', 'Comedy', 'Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Harry Potter y la piedra filosofal', 'calificacion': 7.9, 'vistas': 183.503, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Sing 2: ¡Ven y canta de nuevo!', 'calificacion': 8, 'vistas': 185.81, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Family']}
# {'nombre': 'Glass Onion: Un misterio de Knives Out', 'calificacion': 7.1, 'vistas': 148.425, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Crime', 'Mystery']}
# {'nombre': 'Rápidos y furiosos 9', 'calificacion': 7.2, 'vistas': 169.94, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Crime', 'Thriller']}
# {'nombre': 'Super rápidos y mega furiosos', 'calificacion': 5, 'vistas': 171.993, 'streaming': [], 'genero': ['Comedy', 'Action']}
# {'nombre': 'Desencantada', 'calificacion': 7, 'vistas': 176.193, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Maravilloso Desastre', 'calificacion': 6.8, 'vistas': 186.873, 'streaming': [], 'genero': ['Romance', 'Drama', 'Comedy']}
# {'nombre': 'Wait With Me', 'calificacion': 4.8, 'vistas': 140.16, 'streaming': [], 'genero': ['Romance']}
# {'nombre': 'Mar de sangre', 'calificacion': 5.8, 'vistas': 168.469, 'streaming': [], 'genero': ['Horror', 'Thriller', 'Action', 'Adventure']}
# {'nombre': 'Eternals', 'calificacion': 7, 'vistas': 176.099, 'streaming': ['Disney Plus'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'The Lair', 'calificacion': 5.8, 'vistas': 178.701, 'streaming': [], 'genero': ['Horror', 'Action']}
# {'nombre': 'Prancer: A Christmas Tale', 'calificacion': 6.6, 'vistas': 130.934, 'streaming': [], 'genero': ['Family', 'Fantasy']}
# {'nombre': 'Kids vs. Aliens', 'calificacion': 6, 'vistas': 145.384, 'streaming': [], 'genero': ['Science Fiction', 'Horror', 'Adventure', 'Action']}
# {'nombre': 'Una noche en el museo: El regreso de Kahmunrah', 'calificacion': 6.9, 'vistas': 135.934, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'El vengador', 'calificacion': 7.3, 'vistas': 140.729, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Crime', 'Thriller']}
# {'nombre': 'Dig', 'calificacion': 4.8, 'vistas': 123.105, 'streaming': [], 'genero': ['Mystery', 'Thriller']}
# {'nombre': 'Al filo del abismo', 'calificacion': 6.6, 'vistas': 165.139, 'streaming': ['Amazon Prime Video'], 'genero': ['Thriller', 'Adventure']}
# {'nombre': 'La ciudad perdida', 'calificacion': 6.6, 'vistas': 145.042, 'streaming': ['Star Plus'], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': 'Rápidos y Furiosos: Hobbs y Shaw', 'calificacion': 6.9, 'vistas': 171.2, 'streaming': [], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': 'Harry Potter y la cámara secreta', 'calificacion': 7.7, 'vistas': 165.345, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Hasta el último hombre', 'calificacion': 8.2, 'vistas': 179.351, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Drama', 'History', 'War']}
# {'nombre': 'La Liga de la Justicia de Zack Snyder', 'calificacion': 8.2, 'vistas': 171.807, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Fantasy', 'Science Fiction']}
# {'nombre': 'Candy Land', 'calificacion': 6.5, 'vistas': 157.89, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Harry Potter y el prisionero de Azkaban', 'calificacion': 8, 'vistas': 142.913, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Uncharted: Fuera del mapa', 'calificacion': 7, 'vistas': 161, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure']}
# {'nombre': 'Desamparados', 'calificacion': 6.3, 'vistas': 143.356, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'DC Liga De Supermascotas', 'calificacion': 7.4, 'vistas': 169.695, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Action', 'Family', 'Comedy', 'Science Fiction']}
# {'nombre': 'The Price We Pay', 'calificacion': 5.9, 'vistas': 156.949, 'streaming': [], 'genero': ['Action', 'Thriller', 'Mystery', 'Crime', 'Horror']}
# {'nombre': 'After: Amor Infinito', 'calificacion': 6.9, 'vistas': 161.887, 'streaming': ['Amazon Prime Video'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'Adentro', 'calificacion': 6, 'vistas': 130.17, 'streaming': [], 'genero': ['Drama', 'Thriller']}
# {'nombre': 'Los Caballeros del Zodiaco: Saint Seiya - El inicio', 'calificacion': 6.8, 'vistas': 185.628, 'streaming': [], 'genero': ['Fantasy', 'Action', 'Adventure']}
# {'nombre': 'Harry Potter y el cáliz de fuego', 'calificacion': 7.8, 'vistas': 151.874, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy', 'Family']}
# {'nombre': 'Transformers: El despertar de las bestias', 'calificacion': 0, 'vistas': 161.633, 'streaming': [], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'La huérfana: El origen', 'calificacion': 6.8, 'vistas': 146.607, 'streaming': ['Amazon Prime Video'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Cruella', 'calificacion': 8.1, 'vistas': 141.689, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Crime']}
# {'nombre': 'Cincuenta sombras de Grey', 'calificacion': 5.9, 'vistas': 144.189, 'streaming': ['Netflix', 'Star Plus', 'Paramount Plus', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Netflix basic with Ads', 'Paramount Plus Apple TV Channel '], 'genero': ['Drama', 'Romance', 'Thriller']}
# {'nombre': 'Agente Fortune: El gran engaño', 'calificacion': 6.7, 'vistas': 153.806, 'streaming': [], 'genero': ['Action', 'Comedy', 'Adventure']}
# {'nombre': 'Abracadabra 2', 'calificacion': 7.4, 'vistas': 132.7, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Comedy', 'Family']}
# {'nombre': 'El teléfono negro', 'calificacion': 7.8, 'vistas': 142.473, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Harry Potter y el misterio del príncipe', 'calificacion': 7.7, 'vistas': 139.928, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'Disquiet', 'calificacion': 6.7, 'vistas': 243.81, 'streaming': [], 'genero': ['Thriller', 'Horror', 'Mystery']}
# {'nombre': 'Detective Knight: Sin piedad', 'calificacion': 6.8, 'vistas': 138.459, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Coco', 'calificacion': 8.2, 'vistas': 127.073, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Fantasy', 'Music', 'Comedy', 'Adventure']}
# {'nombre': 'La Máquina infernal', 'calificacion': 6.6, 'vistas': 144.94, 'streaming': ['Star Plus', 'Paramount Plus', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Thriller', 'Mystery']}
# {'nombre': 'Némesis', 'calificacion': 6.8, 'vistas': 136.396, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Crime', 'Fantasy', 'Science Fiction']}
# {'nombre': "Ripper's Revenge", 'calificacion': 4, 'vistas': 238.35, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Animales fantásticos: Los secretos de Dumbledore', 'calificacion': 6.8, 'vistas': 156.062, 'streaming': ['HBO Max'], 'genero': ['Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Creed: Corazón de campeón', 'calificacion': 7.4, 'vistas': 138.748, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama']}
# {'nombre': 'La sirenita', 'calificacion': 0, 'vistas': 150.263, 'streaming': [], 'genero': ['Adventure', 'Family', 'Fantasy', 'Romance']}
# {'nombre': 'Interestelar', 'calificacion': 8.4, 'vistas': 142.118, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Adventure', 'Drama', 'Science Fiction']}
# {'nombre': 'Una peli de fútbol... y mutantes', 'calificacion': 6.1, 'vistas': 144.846, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'Agente oculto', 'calificacion': 6.3, 'vistas': 111.62, 'streaming': [], 'genero': ['Thriller', 'Drama']}
# {'nombre': 'Tom y Jerry en la Tierra de Nieve', 'calificacion': 6.9, 'vistas': 173.142, 'streaming': [], 'genero': ['Family', 'Comedy', 'Animation', 'Adventure']}
# {'nombre': 'Creed II: Defendiendo el Legado', 'calificacion': 7, 'vistas': 166.95, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama']}
# {'nombre': 'La Era de Hielo: Las aventuras de Buck', 'calificacion': 6.7, 'vistas': 135.923, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Adventure', 'Family']}
# {'nombre': 'Enredados', 'calificacion': 7.6, 'vistas': 145.499, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family']}
# {'nombre': 'Cincuenta sombras liberadas', 'calificacion': 6.7, 'vistas': 147.382, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Monsters, Inc.', 'calificacion': 7.8, 'vistas': 138.734, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'Coraline y la puerta secreta', 'calificacion': 7.8, 'vistas': 132.872, 'streaming': [], 'genero': ['Animation', 'Family', 'Fantasy']}
# {'nombre': 'Emily la criminal', 'calificacion': 6.8, 'vistas': 128.937, 'streaming': [], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Wolf Hound', 'calificacion': 6.6, 'vistas': 129.26, 'streaming': [], 'genero': ['War', 'Action']}
# {'nombre': 'Shang-Chi y la leyenda de los Diez Anillos', 'calificacion': 7.6, 'vistas': 127.226, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Asesino sin memoria', 'calificacion': 7, 'vistas': 133.932, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'Piratas del Caribe: Navegando aguas misteriosas', 'calificacion': 6.5, 'vistas': 139.729, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Action', 'Fantasy']}
# {'nombre': 'Lobo adolescente - La película', 'calificacion': 7.7, 'vistas': 147.64, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Action', 'Fantasy', 'TV Movie']}
# {'nombre': 'La Escuela del Bien y del Mal', 'calificacion': 7.2, 'vistas': 115.894, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Fantasy']}
# {'nombre': 'Moonfall: Impacto Lunar', 'calificacion': 6.4, 'vistas': 128.811, 'streaming': ['Amazon Prime Video'], 'genero': ['Science Fiction', 'Adventure', 'Action']}
# {'nombre': 'El Conjuro 3: El Diablo me Obligó a Hacerlo', 'calificacion': 7.5, 'vistas': 113.831, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'El despertar del diablo 2', 'calificacion': 7.6, 'vistas': 133.749, 'streaming': [], 'genero': ['Horror', 'Comedy', 'Fantasy']}
# {'nombre': 'Cómo Entrenar A Tu Dragón 3', 'calificacion': 7.8, 'vistas': 129.133, 'streaming': [], 'genero': ['Animation', 'Family', 'Adventure']}
# {'nombre': 'La noche del demonio: La puerta roja', 'calificacion': 0, 'vistas': 134.17, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Harry Potter y la orden del Fénix', 'calificacion': 7.7, 'vistas': 131.699, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy', 'Mystery']}
# {'nombre': 'Secuestro en directo', 'calificacion': 6.2, 'vistas': 123.693, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'El Hombre del Norte', 'calificacion': 7.1, 'vistas': 132.761, 'streaming': ['HBO Max'], 'genero': ['Action', 'Adventure', 'Fantasy']}
# {'nombre': 'Una historia del Bronx', 'calificacion': 7.8, 'vistas': 130.749, 'streaming': [], 'genero': ['Drama', 'Crime']}
# {'nombre': 'Un jefe en pañales 2: Negocios de familia', 'calificacion': 7.5, 'vistas': 115.246, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Comedy', 'Adventure', 'Family']}
# {'nombre': 'Jack en la caja maldita 2: El despertar', 'calificacion': 6.4, 'vistas': 115.194, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Talentos Ocultos', 'calificacion': 8.1, 'vistas': 143.233, 'streaming': ['Disney Plus'], 'genero': ['Drama', 'History']}
# {'nombre': 'The Avengers: Los Vengadores', 'calificacion': 7.7, 'vistas': 136.619, 'streaming': ['Disney Plus'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'Entre Hermanos', 'calificacion': 7.3, 'vistas': 138.739, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Drama', 'Thriller', 'War']}
# {'nombre': 'Morbius', 'calificacion': 6.2, 'vistas': 116.573, 'streaming': ['HBO Max'], 'genero': ['Action', 'Science Fiction', 'Fantasy']}
# {'nombre': 'Mortal Kombat', 'calificacion': 7.1, 'vistas': 130.036, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Fantasy', 'Adventure']}
# {'nombre': 'Ratatouille', 'calificacion': 7.8, 'vistas': 129.569, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'A Thousand and One', 'calificacion': 8.5, 'vistas': 159.682, 'streaming': [], 'genero': ['Drama']}
# {'nombre': 'Magic Mike: El último baile', 'calificacion': 7.1, 'vistas': 147.241, 'streaming': [], 'genero': ['Comedy', 'Drama', 'Romance']}
# {'nombre': 'Orgasm Inc: La historia de OneTaste', 'calificacion': 6.4, 'vistas': 134.894, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Documentary']}
# {'nombre': 'El lobo de Wall Street', 'calificacion': 8, 'vistas': 124.945, 'streaming': ['HBO Max'], 'genero': ['Crime', 'Drama', 'Comedy']}
# {'nombre': 'Tetris', 'calificacion': 7.9, 'vistas': 126.634, 'streaming': ['Apple TV Plus'], 'genero': ['Thriller', 'History', 'Drama']}
# {'nombre': 'Dog: Un viaje salvaje', 'calificacion': 7.4, 'vistas': 129.601, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Comedy']}
# {'nombre': 'Godzilla: Rey De Los Monstruos', 'calificacion': 6.7, 'vistas': 129.875, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Science Fiction', 'Action']}
# {'nombre': 'Babylon', 'calificacion': 7.5, 'vistas': 129.162, 'streaming': [], 'genero': ['Drama', 'Comedy']}
# {'nombre': 'Yo antes de ti', 'calificacion': 7.9, 'vistas': 128.247, 'streaming': ['Amazon Prime Video', 'MGM Amazon Channel'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Titanic', 'calificacion': 7.9, 'vistas': 140.54, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Shrek 2', 'calificacion': 7.2, 'vistas': 129.974, 'streaming': ['Netflix', 'Amazon Prime Video', 'HBO Max', 'Netflix basic with Ads'], 'genero': ['Animation', 'Family', 'Comedy', 'Fantasy', 'Adventure', 'Romance']}
# {'nombre': 'El rey león', 'calificacion': 8.3, 'vistas': 113.374, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Drama']}
# {'nombre': 'Justicia Implacable', 'calificacion': 7.7, 'vistas': 116.715, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Adventure', 'Crime', 'Thriller']}
# {'nombre': 'Toy Story', 'calificacion': 8, 'vistas': 119.802, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Adventure', 'Family', 'Comedy']}
# {'nombre': 'Rápidos y furiosos 8', 'calificacion': 6.9, 'vistas': 127.62, 'streaming': ['Star Plus'], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Quasi', 'calificacion': 4.9, 'vistas': 135.956, 'streaming': ['Star Plus'], 'genero': ['Comedy']}
# {'nombre': 'Lightyear', 'calificacion': 7.1, 'vistas': 120.193, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Action', 'Adventure', 'Family', 'Science Fiction']}
# {'nombre': 'El Misterio de Ozarks', 'calificacion': 6.3, 'vistas': 111.879, 'streaming': [], 'genero': ['Western', 'Horror', 'Mystery']}
# {'nombre': 'Guia de Viaje hacia el Amor', 'calificacion': 6.8, 'vistas': 196.882, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Romance', 'Comedy', 'Adventure']}
# {'nombre': 'Harry Potter y las reliquias de la muerte: Parte 2', 'calificacion': 8.1, 'vistas': 123.915, 'streaming': ['HBO Max'], 'genero': ['Fantasy', 'Adventure']}
# {'nombre': 'Resident Evil: Bienvenidos a Raccoon City', 'calificacion': 6.1, 'vistas': 125.551, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Science Fiction', 'Action']}
# {'nombre': 'Piratas del Caribe: La maldición de la Perla Negra', 'calificacion': 7.8, 'vistas': 128.981, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'Cruel Fixation', 'calificacion': 6.9, 'vistas': 117.069, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Out of the Blue', 'calificacion': 4.6, 'vistas': 117.158, 'streaming': [], 'genero': ['Thriller', 'Romance']}
# {'nombre': 'Susurro', 'calificacion': 6.4, 'vistas': 108.909, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'La era de hielo', 'calificacion': 7.3, 'vistas': 106.627, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family', 'Adventure']}
# {'nombre': 'Dirty Little Secret', 'calificacion': 7.3, 'vistas': 84.149, 'streaming': [], 'genero': ['Drama', 'TV Movie']}
# {'nombre': 'La sirenita', 'calificacion': 7.3, 'vistas': 122.019, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Fantasy']}
# {'nombre': 'Las locuras del emperador', 'calificacion': 7.5, 'vistas': 130.469, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Animation', 'Comedy', 'Family', 'Fantasy']}
# {'nombre': 'Vista por última vez', 'calificacion': 6.6, 'vistas': 107.27, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Maze Runner: Correr o morir', 'calificacion': 7.2, 'vistas': 115.099, 'streaming': ['Star Plus'], 'genero': ['Action', 'Mystery', 'Science Fiction', 'Thriller']}
# {'nombre': 'Piratas del Caribe: En el Fin del Mundo', 'calificacion': 7.2, 'vistas': 126.871, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'El Último Dragón', 'calificacion': 6.9, 'vistas': 104.61, 'streaming': ['Amazon Prime Video'], 'genero': ['Fantasy', 'Adventure', 'Action']}
# {'nombre': 'The Covenant', 'calificacion': 8.4, 'vistas': 113.833, 'streaming': [], 'genero': ['Action', 'Drama', 'War']}
# {'nombre': 'La Guerra Del Mañana', 'calificacion': 7.9, 'vistas': 104.691, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Science Fiction', 'Adventure']}
# {'nombre': 'Los campeones', 'calificacion': 7.1, 'vistas': 100.371, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'The Minute You Wake Up Dead', 'calificacion': 5.8, 'vistas': 109.301, 'streaming': [], 'genero': ['Thriller', 'Crime']}
# {'nombre': 'Big Hero 6', 'calificacion': 7.7, 'vistas': 119.592, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Family', 'Animation', 'Action', 'Comedy']}
# {'nombre': 'Piratas del Caribe: El cofre de la muerte', 'calificacion': 7.3, 'vistas': 112.226, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Fantasy', 'Action']}
# {'nombre': 'Air: La historia detrás del logo', 'calificacion': 7.6, 'vistas': 118.051, 'streaming': [], 'genero': ['Drama', 'History']}
# {'nombre': 'Rápidos y Furiosos 7', 'calificacion': 7.2, 'vistas': 136.005, 'streaming': ['HBO Max'], 'genero': ['Action', 'Thriller', 'Crime']}
# {'nombre': 'X', 'calificacion': 6.8, 'vistas': 113.843, 'streaming': ['Amazon Prime Video'], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Un paraíso peligroso', 'calificacion': 5.8, 'vistas': 111.648, 'streaming': [], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Power Rangers', 'calificacion': 6.3, 'vistas': 90.129, 'streaming': ['Netflix', 'Amazon Prime Video', 'Netflix basic with Ads'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Praise This', 'calificacion': 7.7, 'vistas': 94.542, 'streaming': [], 'genero': ['Comedy', 'Music']}
# {'nombre': 'El meme maldito', 'calificacion': 5.3, 'vistas': 101.678, 'streaming': ['Star Plus'], 'genero': ['Horror']}
# {'nombre': 'El cuartel secreto', 'calificacion': 6.8, 'vistas': 92.794, 'streaming': ['Star Plus', 'Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel'], 'genero': ['Action', 'Adventure', 'Comedy', 'Science Fiction', 'Family']}
# {'nombre': 'Cars 3', 'calificacion': 6.9, 'vistas': 118.574, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Adventure', 'Comedy', 'Family']}
# {'nombre': 'Renfield: Asistente de vampiro', 'calificacion': 6.9, 'vistas': 113.077, 'streaming': [], 'genero': ['Comedy', 'Horror', 'Fantasy']}
# {'nombre': 'Luca', 'calificacion': 7.9, 'vistas': 112.037, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Fantasy', 'Adventure', 'Family']}
# {'nombre': 'Shrek Para Siempre el Capítulo Final', 'calificacion': 6.3, 'vistas': 101.431, 'streaming': [], 'genero': ['Comedy', 'Adventure', 'Fantasy', 'Animation', 'Family']}
# {'nombre': 'Quiebre', 'calificacion': 6.6, 'vistas': 91.855, 'streaming': [], 'genero': ['Crime', 'Drama', 'Thriller']}
# {'nombre': 'Invitación al Infierno', 'calificacion': 6.3, 'vistas': 102.091, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Invicto 4: La gran pelea', 'calificacion': 7.1, 'vistas': 105.637, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Drama']}
# {'nombre': '¡Nop!', 'calificacion': 6.9, 'vistas': 111.615, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Mystery', 'Science Fiction']}
# {'nombre': 'Los Croods 2: Una Nueva Era', 'calificacion': 7.5, 'vistas': 116.686, 'streaming': [], 'genero': ['Animation', 'Family', 'Adventure', 'Fantasy', 'Comedy']}
# {'nombre': 'La cenicienta', 'calificacion': 7, 'vistas': 98.893, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Fantasy', 'Animation', 'Romance']}
# {'nombre': 'Maneater', 'calificacion': 4.9, 'vistas': 105.777, 'streaming': [], 'genero': ['Mystery', 'Thriller', 'Horror']}
# {'nombre': 'Monstruo del mar', 'calificacion': 7.5, 'vistas': 114.165, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Animation', 'Adventure', 'Family', 'Fantasy']}
# {'nombre': 'On a Wing and a Prayer', 'calificacion': 6.5, 'vistas': 94.828, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Thriller']}
# {'nombre': 'Enola Holmes 2', 'calificacion': 7.6, 'vistas': 105.812, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Adventure', 'Mystery', 'Comedy', 'Crime']}
# {'nombre': 'Harry Potter y las reliquias de la muerte (1ª parte)', 'calificacion': 7.8, 'vistas': 114.349, 'streaming': ['HBO Max'], 'genero': ['Adventure', 'Fantasy']}
# {'nombre': 'El niño con el pijama de rayas', 'calificacion': 7.8, 'vistas': 97.767, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['War', 'Drama', 'History']}
# {'nombre': 'Deadpool', 'calificacion': 7.6, 'vistas': 119.523, 'streaming': ['Disney Plus', 'Star Plus'], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': 'La Gran Aventura de Blue en la Ciudad', 'calificacion': 7.4, 'vistas': 101.372, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Family', 'Adventure', 'Music', 'Animation']}
# {'nombre': 'Hay algo mal con los niños', 'calificacion': 6, 'vistas': 114.048, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'High Heat', 'calificacion': 6, 'vistas': 92.312, 'streaming': [], 'genero': ['Action', 'Comedy', 'Crime']}
# {'nombre': 'After: Aquí empieza todo', 'calificacion': 7.1, 'vistas': 118.303, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'El Entresuelo', 'calificacion': 6.5, 'vistas': 99.441, 'streaming': ['Star Plus'], 'genero': ['Thriller']}
# {'nombre': 'El Escuadrón Suicida', 'calificacion': 7.6, 'vistas': 109.612, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Comedy', 'Adventure']}
# {'nombre': 'Guardianes de la Galaxia: Especial de las fiestas', 'calificacion': 7.3, 'vistas': 105.887, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Science Fiction', 'Adventure']}
# {'nombre': '¡Shazam!', 'calificacion': 7, 'vistas': 98.69, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Action', 'Comedy', 'Fantasy']}
# {'nombre': 'Cars 2', 'calificacion': 6.1, 'vistas': 107.739, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Comedy']}
# {'nombre': 'Mulán', 'calificacion': 7.9, 'vistas': 104.869, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure']}
# {'nombre': 'Avengers: Endgame', 'calificacion': 8.3, 'vistas': 113.382, 'streaming': ['Disney Plus'], 'genero': ['Adventure', 'Science Fiction', 'Action']}
# {'nombre': 'Crepúsculo', 'calificacion': 6.3, 'vistas': 118.075, 'streaming': ['Netflix', 'Amazon Prime Video', 'Starz Play Amazon Channel', 'Netflix basic with Ads', 'Lionsgate Plus'], 'genero': ['Fantasy', 'Drama', 'Romance']}
# {'nombre': 'Los Tipos Malos', 'calificacion': 7.7, 'vistas': 104.849, 'streaming': ['HBO Max'], 'genero': ['Animation', 'Action', 'Adventure', 'Crime', 'Comedy', 'Family']}
# {'nombre': 'Matrix resurrecciones', 'calificacion': 6.5, 'vistas': 105.689, 'streaming': ['HBO Max'], 'genero': ['Science Fiction', 'Action', 'Adventure']}
# {'nombre': 'American Pie Presenta: La Casa Beta', 'calificacion': 5.6, 'vistas': 95.491, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'Free Guy: Tomando el control', 'calificacion': 7.6, 'vistas': 106.837, 'streaming': ['Star Plus'], 'genero': ['Comedy', 'Adventure', 'Science Fiction']}
# {'nombre': 'Todo en todas partes al mismo tiempo', 'calificacion': 7.9, 'vistas': 107.021, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Infinito', 'calificacion': 6.6, 'vistas': 99.312, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel'], 'genero': ['Science Fiction', 'Action', 'Thriller']}
# {'nombre': 'Black Widow', 'calificacion': 7.3, 'vistas': 99.197, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Toy Story 2', 'calificacion': 7.6, 'vistas': 97.404, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Comedy', 'Family']}
# {'nombre': 'Alerta roja', 'calificacion': 6.8, 'vistas': 102.301, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Comedy', 'Crime', 'Thriller']}
# {'nombre': 'Pinocho', 'calificacion': 6.5, 'vistas': 94.856, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Adventure', 'Family']}
# {'nombre': 'El Hombre Gris', 'calificacion': 7, 'vistas': 100.885, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'El cadáver de la novia', 'calificacion': 7.5, 'vistas': 97.347, 'streaming': ['HBO Max'], 'genero': ['Romance', 'Fantasy', 'Animation']}
# {'nombre': 'The Independent', 'calificacion': 7.3, 'vistas': 90.091, 'streaming': [], 'genero': ['Thriller', 'Drama']}
# {'nombre': 'Cómo entrenar a tu dragón 2', 'calificacion': 7.7, 'vistas': 97.998, 'streaming': ['Netflix', 'Amazon Prime Video', 'HBO Max', 'Netflix basic with Ads'], 'genero': ['Fantasy', 'Action', 'Adventure', 'Animation', 'Comedy', 'Family']}
# {'nombre': 'Hellraiser', 'calificacion': 6.4, 'vistas': 102.655, 'streaming': [], 'genero': ['Horror', 'Mystery']}
# {'nombre': 'Pandemia: La guerra final', 'calificacion': 6, 'vistas': 94.419, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Lou', 'calificacion': 6.7, 'vistas': 98.38, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'After: Almas Perdidas', 'calificacion': 7.1, 'vistas': 112.114, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'El Conjuro', 'calificacion': 7.5, 'vistas': 107.386, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Sonic: La Película', 'calificacion': 7.4, 'vistas': 106.331, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Comedy', 'Family']}
# {'nombre': 'Los crímenes de la academia', 'calificacion': 7, 'vistas': 101.094, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Mystery', 'Thriller']}
# {'nombre': 'Raya y el último dragón', 'calificacion': 7.9, 'vistas': 102.939, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Fantasy', 'Action', 'Adventure']}
# {'nombre': 'After: En mil pedazos', 'calificacion': 7.2, 'vistas': 110.473, 'streaming': ['Amazon Prime Video'], 'genero': ['Romance', 'Drama']}
# {'nombre': 'Buscando a Nemo', 'calificacion': 7.8, 'vistas': 93.741, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family']}
# {'nombre': '¿Qué Pasó Ayer?', 'calificacion': 7.3, 'vistas': 97.31, 'streaming': ['HBO Max'], 'genero': ['Comedy']}
# {'nombre': 'Sueño de fuga', 'calificacion': 8.7, 'vistas': 151.657, 'streaming': ['HBO Max'], 'genero': ['Drama', 'Crime']}
# {'nombre': 'Blood', 'calificacion': 5.8, 'vistas': 92.948, 'streaming': [], 'genero': ['Thriller', 'Horror']}
# {'nombre': 'Arctic Void', 'calificacion': 5, 'vistas': 82.82, 'streaming': [], 'genero': ['Science Fiction', 'Thriller']}
# {'nombre': 'Monstrous', 'calificacion': 6, 'vistas': 107.201, 'streaming': [], 'genero': ['Horror', 'Mystery', 'Thriller']}
# {'nombre': 'Shrek tercero', 'calificacion': 6.3, 'vistas': 90.565, 'streaming': [], 'genero': ['Fantasy', 'Adventure', 'Animation', 'Comedy', 'Family']}
# {'nombre': 'Duna', 'calificacion': 7.8, 'vistas': 107.924, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Science Fiction', 'Adventure']}
# {'nombre': 'Pánico a la deriva', 'calificacion': 5, 'vistas': 93.221, 'streaming': ['Star Plus', 'Paramount Plus', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Paramount Plus Apple TV Channel '], 'genero': ['Thriller', 'Horror']}
# {'nombre': 'Cómo Entrenar A Tu Dragón', 'calificacion': 7.8, 'vistas': 90.33, 'streaming': ['Paramount Plus', 'HBO Max', 'Cinépolis KLIC', 'Paramount+ Amazon Channel'], 'genero': ['Fantasy', 'Adventure', 'Animation', 'Family']}
# {'nombre': 'El Padrino', 'calificacion': 8.7, 'vistas': 103.436, 'streaming': ['Netflix', 'Star Plus', 'Paramount Plus', 'Cinépolis KLIC', 'Paramount+ Amazon Channel', 'Netflix basic with Ads'], 'genero': ['Drama', 'Crime']}
# {'nombre': 'La noche del demonio', 'calificacion': 6.9, 'vistas': 79.821, 'streaming': ['HBO Max'], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Gato con botas', 'calificacion': 6.5, 'vistas': 89.226, 'streaming': [], 'genero': ['Comedy', 'Fantasy', 'Animation', 'Romance', 'Adventure', 'Family']}
# {'nombre': 'Avengers: Era de Ultrón', 'calificacion': 7.3, 'vistas': 104.249, 'streaming': ['Disney Plus'], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Gigantes de Acero', 'calificacion': 7, 'vistas': 97.581, 'streaming': [], 'genero': ['Action', 'Science Fiction', 'Drama']}
# {'nombre': 'Halloween: La noche final', 'calificacion': 6.3, 'vistas': 75.554, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': 'Invicto 3: Redención', 'calificacion': 7.5, 'vistas': 97.372, 'streaming': [], 'genero': ['Action', 'Thriller']}
# {'nombre': 'Corazones De Hierro', 'calificacion': 7.5, 'vistas': 97.958, 'streaming': ['Netflix', 'Amazon Prime Video', 'Star Plus', 'Netflix basic with Ads'], 'genero': ['War', 'Drama', 'Action']}
# {'nombre': 'Son como niños 2', 'calificacion': 6.1, 'vistas': 104.578, 'streaming': ['HBO Max'], 'genero': ['Comedy']}
# ...
# {'nombre': 'Mi Pobre Diablillo', 'calificacion': 6, 'vistas': 18.654, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Family']}
# {'nombre': 'Huracán: Categoría 5', 'calificacion': 5.7, 'vistas': 20.163, 'streaming': ['Netflix', 'FilmBox+', 'Netflix basic with Ads'], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Vaselina 2', 'calificacion': 5.1, 'vistas': 21.104, 'streaming': [], 'genero': ['Comedy', 'Music', 'Romance']}
# {'nombre': 'La pirámide', 'calificacion': 5.2, 'vistas': 18.159, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'UglyDolls: Extraordinariamente Feos', 'calificacion': 6.7, 'vistas': 18.915, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Family', 'Animation', 'Music']}
# {'nombre': 'El lenguaje de los sueños', 'calificacion': 6.6, 'vistas': 16.304, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Llegamos en son de paz', 'calificacion': 5.7, 'vistas': 19.355, 'streaming': ['Star Plus'], 'genero': ['Action', 'Comedy', 'Science Fiction']}
# {'nombre': 'Zambezia', 'calificacion': 6, 'vistas': 16.804, 'streaming': ['Amazon Prime Video', 'Claro video'], 'genero': ['Comedy', 'Animation', 'Adventure', 'Family']}
# {'nombre': 'Final: The Rapture', 'calificacion': 4.4, 'vistas': 13.765, 'streaming': [], 'genero': ['Thriller']}
# {'nombre': 'Después del apocalipsis', 'calificacion': 5.8, 'vistas': 17.91, 'streaming': [], 'genero': ['Drama', 'Horror', 'Romance', 'Science Fiction']}
# {'nombre': 'Comando Kill', 'calificacion': 5.5, 'vistas': 21.657, 'streaming': ['Amazon Prime Video'], 'genero': ['Action', 'Horror', 'Science Fiction']}
# {'nombre': 'Frio De Perros', 'calificacion': 5.6, 'vistas': 16.652, 'streaming': ['Disney Plus'], 'genero': ['Comedy', 'Family', 'Adventure']}
# {'nombre': 'Los Blancos no saben Saltar', 'calificacion': 6.6, 'vistas': 27.066, 'streaming': ['Star Plus'], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'Los Coneheads', 'calificacion': 5.3, 'vistas': 17.4, 'streaming': [], 'genero': ['Comedy', 'Science Fiction', 'Family']}
# {'nombre': 'Tucker y Dale En contra del mal', 'calificacion': 7.4, 'vistas': 17.902, 'streaming': [], 'genero': ['Comedy', 'Horror']}
# {'nombre': 'Avión Presidencial', 'calificacion': 6.5, 'vistas': 18.899, 'streaming': ['Star Plus'], 'genero': ['Action', 'Thriller']}
# {'nombre': 'El Templo', 'calificacion': 5.2, 'vistas': 15.906, 'streaming': [], 'genero': ['Action', 'Horror', 'Thriller']}
# {'nombre': 'El Cazador de Wolf Creek 2', 'calificacion': 6.4, 'vistas': 14.402, 'streaming': [], 'genero': ['Horror', 'Thriller']}
# {'nombre': '¿Quieres ser John Malkovich?', 'calificacion': 7.4, 'vistas': 19.298, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Drama', 'Fantasy']}
# {'nombre': 'Ted Bundy: Durmiendo con el asesino', 'calificacion': 7, 'vistas': 20.408, 'streaming': [], 'genero': ['Crime']}
# {'nombre': 'El infiltrado', 'calificacion': 6.1, 'vistas': 14.399, 'streaming': ['HBO Max'], 'genero': ['Thriller', 'Drama', 'Action']}
# {'nombre': 'Locura en el oeste', 'calificacion': 7.3, 'vistas': 16.895, 'streaming': [], 'genero': ['Western', 'Comedy']}
# {'nombre': 'Venganza: Una historia de amor', 'calificacion': 5.6, 'vistas': 16.902, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action', 'Drama', 'Thriller']}
# {'nombre': 'Café Society', 'calificacion': 6.5, 'vistas': 11.579, 'streaming': [], 'genero': ['Comedy', 'Drama', 'Romance']}
# {'nombre': 'Intersect', 'calificacion': 5.6, 'vistas': 17.339, 'streaming': [], 'genero': ['Horror', 'Science Fiction', 'Thriller']}
# {'nombre': 'Revelaciones', 'calificacion': 6.4, 'vistas': 18.895, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Horror', 'Mystery', 'Thriller']}
# {'nombre': 'El Chacal', 'calificacion': 6.3, 'vistas': 18.393, 'streaming': [], 'genero': ['Action', 'Thriller', 'Adventure', 'Crime']}
# {'nombre': 'El canto del cisne', 'calificacion': 7.3, 'vistas': 18.43, 'streaming': ['Apple TV Plus'], 'genero': ['Drama', 'Science Fiction']}
# {'nombre': 'Slaughterhouse: Escuela sangrienta', 'calificacion': 5.5, 'vistas': 16.902, 'streaming': [], 'genero': ['Action', 'Comedy', 'Fantasy', 'Horror']}
# {'nombre': 'Preciosa', 'calificacion': 7.4, 'vistas': 17.394, 'streaming': ['Amazon Prime Video', 'Claro video'], 'genero': ['Drama']}
# {'nombre': 'All Quiet on the Western Front', 'calificacion': 6.6, 'vistas': 17.392, 'streaming': [], 'genero': ['War', 'Drama', 'TV Movie']}
# {'nombre': 'Pequeña Miss Sunshine', 'calificacion': 7.7, 'vistas': 16.045, 'streaming': ['Star Plus'], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'La venganza del muerto', 'calificacion': 7.4, 'vistas': 17.891, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Western', 'Drama', 'Mystery']}
# {'nombre': 'El demonio neón', 'calificacion': 6.5, 'vistas': 15.897, 'streaming': ['Amazon Prime Video', 'MUBI'], 'genero': ['Thriller', 'Horror']}
# {'nombre': 'El sabotaje', 'calificacion': 5.6, 'vistas': 19.145, 'streaming': [], 'genero': ['Action', 'Drama', 'Thriller', 'Crime']}
# {'nombre': 'Sentencia De Muerte', 'calificacion': 6.2, 'vistas': 16.14, 'streaming': ['MGM Amazon Channel'], 'genero': ['Action', 'Crime', 'Thriller']}
# {'nombre': 'Sextillizos', 'calificacion': 6.3, 'vistas': 15.903, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy']}
# {'nombre': 'La reina de los condenados', 'calificacion': 6.1, 'vistas': 13.889, 'streaming': [], 'genero': ['Drama', 'Fantasy', 'Horror']}
# {'nombre': 'El mundo está loco, loco, loco, loco', 'calificacion': 7, 'vistas': 23.889, 'streaming': [], 'genero': ['Action', 'Adventure', 'Comedy']}
# {'nombre': 'Rey de reyes', 'calificacion': 7.1, 'vistas': 20.139, 'streaming': [], 'genero': ['Drama', 'History']}
# {'nombre': 'Locos por las nueces', 'calificacion': 5.8, 'vistas': 13.142, 'streaming': [], 'genero': ['Animation', 'Comedy', 'Family', 'Adventure']}
# {'nombre': 'Vanilla Sky', 'calificacion': 6.8, 'vistas': 20.388, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Mystery', 'Science Fiction', 'Drama', 'Romance', 'Fantasy', 'Thriller']}
# {'nombre': 'Los Ángeles al desnudo', 'calificacion': 7.8, 'vistas': 17.137, 'streaming': ['Amazon Prime Video', 'Star Plus', 'HBO Max'], 'genero': ['Crime', 'Mystery', 'Thriller']}
# {'nombre': 'Lucha por la libertad', 'calificacion': 6.7, 'vistas': 14.892, 'streaming': ['Claro video'], 'genero': ['Action', 'Drama', 'History', 'War']}
# {'nombre': 'Demolición', 'calificacion': 6.8, 'vistas': 15.091, 'streaming': ['Claro video'], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'Mente siniestra', 'calificacion': 6.4, 'vistas': 22.387, 'streaming': ['Star Plus'], 'genero': ['Horror', 'Mystery']}
# {'nombre': 'El final de la cuenta atrás', 'calificacion': 6.6, 'vistas': 19.135, 'streaming': [], 'genero': ['War', 'Action', 'Science Fiction']}
# {'nombre': 'El destructor mortal', 'calificacion': 6, 'vistas': 16.635, 'streaming': ['MGM Amazon Channel'], 'genero': ['Action', 'Thriller', 'Science Fiction', 'Crime', 'Horror']}
# {'nombre': 'El misterio de la libélula', 'calificacion': 6.5, 'vistas': 15.136, 'streaming': [], 'genero': ['Thriller', 'Fantasy']}
# {'nombre': 'Erin Brockovich, una mujer audaz', 'calificacion': 7.4, 'vistas': 21.636, 'streaming': [], 'genero': ['Drama']}
# {'nombre': 'S.O.S. Hay un loco suelto en el espacio', 'calificacion': 6.8, 'vistas': 17.335, 'streaming': ['MGM Amazon Channel'], 'genero': ['Comedy', 'Science Fiction']}
# {'nombre': 'La Amante de mi Padre', 'calificacion': 6.4, 'vistas': 19.142, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama']}
# {'nombre': "World's Greatest Dad", 'calificacion': 6.6, 'vistas': 17.634, 'streaming': ['Amazon Prime Video'], 'genero': ['Comedy', 'Romance', 'Drama']}
# {'nombre': 'Dr. Cable: El desastre llama', 'calificacion': 6, 'vistas': 17.631, 'streaming': [], 'genero': ['Comedy', 'Drama', 'Thriller']}
# {'nombre': 'Casi famosos', 'calificacion': 7.5, 'vistas': 17.082, 'streaming': ['Star Plus'], 'genero': ['Drama', 'Music']}
# {'nombre': 'Ciudad de sombras', 'calificacion': 5.9, 'vistas': 17.885, 'streaming': ['Netflix', 'Amazon Prime Video', 'Netflix basic with Ads'], 'genero': ['Thriller', 'Crime', 'Drama']}
# {'nombre': 'Halloween III: El imperio de las brujas', 'calificacion': 5.1, 'vistas': 16.129, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Horror', 'Mystery', 'Science Fiction']}
# {'nombre': 'Patinando a la Gloria', 'calificacion': 6.1, 'vistas': 18.631, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'La Deuda', 'calificacion': 5.9, 'vistas': 25.388, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Action']}
# {'nombre': 'Sr. Link', 'calificacion': 7, 'vistas': 19.641, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Animation', 'Comedy', 'Adventure', 'Fantasy']}
# {'nombre': 'Demoniaca', 'calificacion': 6.1, 'vistas': 21.398, 'streaming': [], 'genero': ['Horror', 'Drama', 'Mystery']}
# {'nombre': 'Death Note', 'calificacion': 4.2, 'vistas': 17.136, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Crime', 'Fantasy', 'Horror', 'Thriller']}
# {'nombre': 'La delgada línea roja', 'calificacion': 7.5, 'vistas': 18.378, 'streaming': ['Star Plus'], 'genero': ['Drama', 'History', 'War']}
# {'nombre': 'Patch Adams', 'calificacion': 7.3, 'vistas': 20.376, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Drama']}
# {'nombre': 'Jackie Brown', 'calificacion': 7.4, 'vistas': 21.076, 'streaming': [], 'genero': ['Crime', 'Thriller', 'Drama']}
# {'nombre': 'Winnie the Pooh', 'calificacion': 6.9, 'vistas': 19.578, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure']}
# {'nombre': 'El Supremo', 'calificacion': 6.8, 'vistas': 15.134, 'streaming': [], 'genero': ['Action', 'Crime']}
# {'nombre': 'Ultimo viaje las vegas', 'calificacion': 6.4, 'vistas': 15.128, 'streaming': ['Starz Play Amazon Channel', 'Lionsgate Plus'], 'genero': ['Comedy']}
# {'nombre': 'Un plan no tan perfecto', 'calificacion': 5.4, 'vistas': 15.126, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Crime']}
# {'nombre': 'La guerra de los mundos', 'calificacion': 6.8, 'vistas': 14.874, 'streaming': [], 'genero': ['Science Fiction', 'Action']}
# {'nombre': 'Viviendo con mi ex', 'calificacion': 5.8, 'vistas': 20.374, 'streaming': [], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Chicos Buenos', 'calificacion': 6.9, 'vistas': 20.385, 'streaming': [], 'genero': ['Comedy']}
# {'nombre': 'Una historia de venganza', 'calificacion': 5.7, 'vistas': 20.379, 'streaming': ['Amazon Prime Video'], 'genero': ['Drama', 'Thriller']}
# {'nombre': 'Dr. Insólito o: Cómo aprendí a dejar de preocuparme y amar la bomba', 'calificacion': 8.1, 'vistas': 18.572, 'streaming': [], 'genero': ['Drama', 'Comedy', 'War']}
# {'nombre': 'Plan de Escape 3: El rescate', 'calificacion': 5.3, 'vistas': 21.618, 'streaming': ['Paramount Plus', 'Claro video', 'Cinépolis KLIC', 'Paramount+ Amazon Channel'], 'genero': ['Action']}
# {'nombre': 'El escape perfecto', 'calificacion': 6.3, 'vistas': 20.822, 'streaming': [], 'genero': ['Thriller', 'Mystery', 'Adventure']}
# {'nombre': 'The Tank', 'calificacion': 2, 'vistas': 14.504, 'streaming': [], 'genero': ['Horror']}
# {'nombre': 'Autodestrucción', 'calificacion': 4.8, 'vistas': 16.626, 'streaming': ['Amazon Prime Video'], 'genero': ['Science Fiction', 'Action', 'Thriller']}
# {'nombre': 'LEGO Star Wars: Especial de las Fiestas', 'calificacion': 6.7, 'vistas': 15.388, 'streaming': ['Disney Plus'], 'genero': ['Animation', 'Family', 'Adventure', 'Comedy', 'Science Fiction', 'Action', 'TV Movie']}
# {'nombre': 'Nuestra Pandilla', 'calificacion': 7.5, 'vistas': 23.018, 'streaming': ['Disney Plus'], 'genero': ['Family', 'Comedy']}
# {'nombre': 'El Libro de Las Sombras: Bruja Blair 2', 'calificacion': 4.2, 'vistas': 21.369, 'streaming': [], 'genero': ['Mystery', 'Thriller', 'Horror']}
# {'nombre': 'Mi papá es un gato', 'calificacion': 5.7, 'vistas': 19.373, 'streaming': ['Amazon Prime Video', 'HBO Max'], 'genero': ['Fantasy', 'Comedy', 'Family']}
# {'nombre': 'Viudas', 'calificacion': 6.5, 'vistas': 21.327, 'streaming': ['Netflix', 'Star Plus', 'Netflix basic with Ads'], 'genero': ['Crime', 'Thriller']}
# {'nombre': 'Frida', 'calificacion': 7.4, 'vistas': 19.118, 'streaming': [], 'genero': ['Drama', 'Romance']}
# {'nombre': 'Cariño, cuánto te odio', 'calificacion': 7.4, 'vistas': 20.652, 'streaming': ['Amazon Prime Video'], 'genero': ['Romance', 'Comedy']}
# {'nombre': 'Osa Polar', 'calificacion': 7.4, 'vistas': 16.885, 'streaming': ['Disney Plus'], 'genero': ['Documentary']}
# {'nombre': 'Supergirl', 'calificacion': 5.5, 'vistas': 16.114, 'streaming': [], 'genero': ['Adventure', 'Fantasy', 'Action', 'Science Fiction']}
# {'nombre': 'Bienvenidos a Monster High', 'calificacion': 6.8, 'vistas': 16.87, 'streaming': [], 'genero': ['Animation', 'Family']}
# {'nombre': 'Power Rangers Super Megaforce: The Legendary Battle', 'calificacion': 7.1, 'vistas': 14.308, 'streaming': [], 'genero': ['Action', 'Adventure', 'Science Fiction']}
# {'nombre': 'Héroe de centro comercial', 'calificacion': 5.4, 'vistas': 22.715, 'streaming': ['Star Plus', 'Claro video'], 'genero': ['Action', 'Adventure', 'Comedy', 'Family']}
# {'nombre': 'El final de todo', 'calificacion': 5.3, 'vistas': 19.373, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Science Fiction', 'Thriller', 'Mystery', 'Action', 'Adventure']}
# {'nombre': 'El golpe', 'calificacion': 8, 'vistas': 17.362, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Comedy', 'Crime', 'Drama']}
# {'nombre': 'El violinista en el tejado', 'calificacion': 7.7, 'vistas': 15.862, 'streaming': ['MGM Amazon Channel'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'La Princesa Encantada', 'calificacion': 6.6, 'vistas': 16.862, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Family', 'Animation', 'Fantasy', 'Adventure', 'Comedy']}
# {'nombre': 'El Devorador de Pecados', 'calificacion': 5.7, 'vistas': 15.613, 'streaming': [], 'genero': ['Drama', 'Fantasy', 'Horror', 'Mystery', 'Romance', 'Thriller']}
# {'nombre': 'La casa de los 1000 cuerpos', 'calificacion': 6.2, 'vistas': 16.362, 'streaming': [], 'genero': ['Horror', 'Crime']}
# {'nombre': 'Guardianes de la tumba', 'calificacion': 5.6, 'vistas': 17.37, 'streaming': [], 'genero': ['Action', 'Adventure', 'Horror']}
# {'nombre': 'El sacrificio del ciervo sagrado', 'calificacion': 7, 'vistas': 19.869, 'streaming': ['HBO Max'], 'genero': ['Drama', 'Thriller', 'Mystery']}
# {'nombre': 'Mandy', 'calificacion': 6.2, 'vistas': 18.871, 'streaming': [], 'genero': ['Horror', 'Action', 'Thriller', 'Fantasy']}
# {'nombre': 'El Síndrome de Minamata', 'calificacion': 6.9, 'vistas': 12.126, 'streaming': [], 'genero': ['Drama', 'History']}
# {'nombre': 'Paw Patrol: Ready, Race, Rescue!', 'calificacion': 7.1, 'vistas': 13.122, 'streaming': [], 'genero': ['Animation', 'Family']}
# {'nombre': 'Reglas de compromiso', 'calificacion': 6.2, 'vistas': 15.86, 'streaming': [], 'genero': ['War', 'Action', 'Adventure', 'Drama', 'History']}
# {'nombre': 'El planeta desconocido', 'calificacion': 7.3, 'vistas': 17.61, 'streaming': [], 'genero': ['Science Fiction']}
# {'nombre': 'Eragon', 'calificacion': 5.1, 'vistas': 23.061, 'streaming': ['Disney Plus'], 'genero': ['Fantasy', 'Action', 'Adventure', 'Family']}
# {'nombre': 'Definitivamente, tal vez', 'calificacion': 6.9, 'vistas': 18.611, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Romance']}
# {'nombre': 'La última carta de Amor', 'calificacion': 7.5, 'vistas': 16.636, 'streaming': ['Netflix', 'Netflix basic with Ads'], 'genero': ['Drama', 'Romance']}
# {'nombre': 'El engendro', 'calificacion': 5.6, 'vistas': 14.855, 'streaming': ['HBO Max'], 'genero': ['Drama', 'Science Fiction', 'Thriller']}
# {'nombre': 'Babe 2: El puerquito en la ciudad', 'calificacion': 5.6, 'vistas': 17.855, 'streaming': [], 'genero': ['Adventure', 'Comedy', 'Drama', 'Family', 'Fantasy']}
# {'nombre': 'El maestro luchador', 'calificacion': 6.2, 'vistas': 18.107, 'streaming': ['HBO Max'], 'genero': ['Comedy', 'Action']}

# %%
movies_json = json.dumps(movies_data)
with open('movies.json', 'w') as file:
    file.write(movies_json)
